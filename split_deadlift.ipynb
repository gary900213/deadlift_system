# %%
import tkinter as tk
from tkinter import filedialog
from matplotlib.figure import Figure
from matplotlib.backends.backend_tkagg import FigureCanvasTkAgg
import numpy as np
import os

def read_skeleton_data(filename):
    data = {}
    with open(filename, 'r') as file:
        for line in file:
            values = line.strip().split(',')
            if len(values) < 4:
                print(f"Skipping malformed line: {line.strip()}")
                continue
            try:
                frame, joint, x, y = map(int, values[:4])
                if frame not in data:
                    data[frame] = {}
                data[frame][joint] = (x, y)
            except ValueError as e:
                print(f"Error parsing line: {line.strip()} - {e}")
                continue
    return data

def calculate_angles_and_length(data):
    frames = sorted(data.keys())
    left_knee_angles, left_hip_angles, body_lengths = [], [], []

    for frame in frames:
        joints = data[frame]
        if all(k in joints for k in [12, 14, 16, 6, 10]):
            left_knee_angles.append(calculate_angle(joints[12], joints[14], joints[16]))
            left_hip_angles.append(calculate_angle(joints[6], joints[12], joints[16]))
            body_lengths.append(calculate_distance(joints[6], joints[12]))

    return frames, left_knee_angles, left_hip_angles, body_lengths

def calculate_angle(p1, p2, p3):
    a, b, c = np.array(p1), np.array(p2), np.array(p3)
    ba, bc = a - b, c - b

    norm_ba = np.linalg.norm(ba)
    norm_bc = np.linalg.norm(bc)

    if norm_ba == 0 or norm_bc == 0:
        return 0

    cosine_angle = np.dot(ba, bc) / (norm_ba * norm_bc)
    cosine_angle = np.clip(cosine_angle, -1.0, 1.0)
    return np.degrees(np.arccos(cosine_angle))

def calculate_distance(p1, p2):
    return np.linalg.norm(np.array(p1) - np.array(p2))


def read_barbell_positions(filename):
    frames, x_coords, y_coords = [], [], []
    with open(filename, 'r') as file:
        for line in file:
            frame, x, y = map(float, line.strip().split(',')[:3])
            frames.append(int(frame))
            x_coords.append(x)
            y_coords.append(y)
    return frames, x_coords, y_coords

def save_plot(fig):
    folder_selected = filedialog.askdirectory(title="Select Folder to Save Plot")
    if folder_selected:
        file_path = os.path.join(folder_selected, "combined_plot.png")
        fig.savefig(file_path)
        print(f"Plot saved to {file_path}")

def on_click(event):
    ax.plot(event.xdata, event.ydata, 'ro')
    canvas.draw()

def motion(event):
    if event.xdata is not None and event.ydata is not None:
        root.title(f"Skeleton and Barbell Metrics - Mouse at ({event.xdata:.2f}, {event.ydata:.2f})")

def plot_metrics_in_tkinter():
    global root, canvas, ax
    root = tk.Tk()
    root.title("Skeleton and Barbell Metrics")
    root.geometry("800x800")

    fig = Figure(figsize=(8, 6), dpi=100)
    ax = fig.add_subplot(1, 1, 1)

    ax.plot(skeleton_frames, left_knee_angles, label='Left Knee Angle', color='blue')
    ax.plot(skeleton_frames, left_hip_angles, label='Left Hip Angle', color='green')
    ax.plot(skeleton_frames, body_lengths, label='Body Length', color='red')
    ax.plot(barbell_frames, x_coords, label='Barbell X Position', color='purple')
    ax.plot(barbell_frames, y_coords, label='Barbell Y Position', color='orange')

    ax.set_title("Combined Metrics Over Time")
    ax.set_xlabel("Frame")
    ax.set_ylabel("Value")
    ax.legend()
    ax.grid()

    canvas = FigureCanvasTkAgg(fig, root)
    canvas.get_tk_widget().pack(fill=tk.BOTH, expand=True)
    canvas.mpl_connect("button_press_event", on_click)
    canvas.mpl_connect("motion_notify_event", motion)

    save_button = tk.Button(root, text="Save Plot", command=lambda: save_plot(fig))
    save_button.pack(pady=10)

    root.mainloop()

# skeleton_file_path = 'D:\\labdata\\MOCAP\\recordings_copy\\受試者27\\recording_20241209_100647\\interpolated_mediapipe_landmarks_1.txt'
skeleton_file_path = 'D:\\labdata\\MOCAP\\recordings_copy\\受試者10\\recording_20241204_100047\\yolo_skeleton_coordinates_1st_interp.txt'
barbell_file_path = 'D:\\labdata\\MOCAP\\recordings_copy\\受試者10\\recording_20241204_100047\\yolo_coordinates_interpolated.txt'

skeleton_data = read_skeleton_data(skeleton_file_path)
skeleton_frames, left_knee_angles, left_hip_angles, body_lengths = calculate_angles_and_length(skeleton_data)
barbell_frames, x_coords, y_coords = read_barbell_positions(barbell_file_path)

plot_metrics_in_tkinter()

# %%
import tkinter as tk
from tkinter import filedialog
from matplotlib.figure import Figure
from matplotlib.backends.backend_tkagg import FigureCanvasTkAgg
import numpy as np
import os
from scipy.signal import find_peaks, savgol_filter

def read_skeleton_data(filename):
    data = {}
    with open(filename, 'r') as file:
        for line in file:
            values = line.strip().split(',')
            if len(values) < 4:
                continue
            try:
                frame, joint, x, y = map(int, values[:4])
                if frame not in data:
                    data[frame] = {}
                data[frame][joint] = (x, y)
            except ValueError:
                continue
    return data

def calculate_angles(data):
    frames = sorted(data.keys())
    angles = []

    for frame in frames:
        joints = data[frame]
        if all(k in joints for k in [11, 13, 15]):
            angles.append(calculate_angle(joints[11], joints[13], joints[15]))
        else:
            angles.append(None)

    return frames, angles

def calculate_angle(p1, p2, p3):
    a, b, c = np.array(p1), np.array(p2), np.array(p3)
    ba, bc = a - b, c - b
    norm_ba = np.linalg.norm(ba)
    norm_bc = np.linalg.norm(bc)
    if norm_ba == 0 or norm_bc == 0:
        return 0
    cosine_angle = np.dot(ba, bc) / (norm_ba * norm_bc)
    cosine_angle = np.clip(cosine_angle, -1.0, 1.0)
    return np.degrees(np.arccos(cosine_angle))

def find_valleys(smoothed_angles, peaks, search_range=10):
    valleys = []
    valleys1 = []
    for peak in peaks:
        # 在峰值前後各 `search_range` 幀內找最小值
        left_bound = max(0, peak - search_range)
        right_bound = min(len(smoothed_angles) - 1, peak + search_range)

        left_min_index = left_bound + np.argmin(smoothed_angles[left_bound:peak])
        right_min_index = peak + np.argmin(smoothed_angles[peak:right_bound + 1])

        valleys.append(left_min_index)
        valleys1.append(right_min_index)

    return np.array(valleys),np.array(valleys1)

def plot_metrics_in_tkinter():
    global root, canvas, ax
    root = tk.Tk()
    root.title("Smoothed Left Knee Angle")
    root.geometry("800x600")

    fig = Figure(figsize=(8, 6), dpi=100)
    ax = fig.add_subplot(1, 1, 1)

    # 過濾掉 None 值
    valid_frames = [frames[i] for i in range(len(left_knee_angles)) if left_knee_angles[i] is not None]
    valid_angles = np.array([angle for angle in left_knee_angles if angle is not None])

    # **平滑化曲線**
    smoothed_angles = savgol_filter(valid_angles, window_length=15, polyorder=3)  # 避免過度震盪

    # 找出 170 度以上的峰值，間隔 10 幀以上
    peaks, _ = find_peaks(smoothed_angles, height=170, distance=10, prominence=5)

    # 找出峰值前後的谷底
    valleys,valleys1 = find_valleys(smoothed_angles, peaks, search_range=50)

    # 繪製平滑化曲線
    ax.plot(valid_frames, smoothed_angles, label='Smoothed Left Knee Angle', color='blue')
    ax.plot(np.array(valid_frames)[peaks], smoothed_angles[peaks], 'ro', label="Peaks")  # 紅色標記峰值
    ax.plot(np.array(valid_frames)[valleys], smoothed_angles[valleys], 'yo', label="Valleys")  # 藍色標記谷底
    ax.plot(np.array(valid_frames)[valleys1], smoothed_angles[valleys1], 'go', label="Valleys1")  # 藍色標記谷底


    ax.set_title("Smoothed Left Knee Angle with Peaks and Valleys")
    ax.set_xlabel("Frame")
    ax.set_ylabel("Angle (degrees)")
    ax.legend()
    ax.grid()

    canvas = FigureCanvasTkAgg(fig, root)
    canvas.get_tk_widget().pack(fill=tk.BOTH, expand=True)

    root.mainloop()

# 設定你的檔案路徑
skeleton_file_path = 'D:\\labdata\\MOCAP\\recordings_copy\\受試者10\\recording_20241204_100047\\yolo_skeleton_coordinates_1st_interp.txt'

# 讀取數據
skeleton_data = read_skeleton_data(skeleton_file_path)
frames, left_knee_angles = calculate_angles(skeleton_data)

# 顯示圖表
plot_metrics_in_tkinter()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 113
#     110 frames, left_knee_angles = calculate_angles(skeleton_data)
#     112 # 顯示圖表
# --> 113 plot_metrics_in_tkinter()
#
# Cell In[2], line 103, in plot_metrics_in_tkinter()
#     100 canvas = FigureCanvasTkAgg(fig, root)
#     101 canvas.get_tk_widget().pack(fill=tk.BOTH, expand=True)
# --> 103 root.mainloop()
#
# File ~\Anaconda3\envs\deadlift\lib\tkinter\__init__.py:1422, in Misc.mainloop(self, n)
#    1420 def mainloop(self, n=0):
#    1421     """Call the mainloop of Tk."""
# -> 1422     self.tk.mainloop(n)
#
# KeyboardInterrupt:

# %%
import tkinter as tk
from tkinter import filedialog
from matplotlib.figure import Figure
from matplotlib.backends.backend_tkagg import FigureCanvasTkAgg
import numpy as np
import os
from scipy.signal import find_peaks, savgol_filter
import cv2

def read_skeleton_data(filename):
    data = {}
    with open(filename, 'r') as file:
        for line in file:
            values = line.strip().split(',')
            if len(values) < 4:
                continue
            try:
                frame, joint, x, y = map(int, values[:4])
                if frame not in data:
                    data[frame] = {}
                data[frame][joint] = (x, y)
            except ValueError:
                continue
    return data

def calculate_angles(data):
    frames = sorted(data.keys())
    angles = []

    for frame in frames:
        joints = data[frame]
        if all(k in joints for k in [12, 14, 16]):
            angles.append(calculate_angle(joints[12], joints[14], joints[16]))
        else:
            angles.append(None)

    return frames, angles

def calculate_angle(p1, p2, p3):
    a, b, c = np.array(p1), np.array(p2), np.array(p3)
    ba, bc = a - b, c - b
    norm_ba = np.linalg.norm(ba)
    norm_bc = np.linalg.norm(bc)
    if norm_ba == 0 or norm_bc == 0:
        return 0
    cosine_angle = np.dot(ba, bc) / (norm_ba * norm_bc)
    cosine_angle = np.clip(cosine_angle, -1.0, 1.0)
    return np.degrees(np.arccos(cosine_angle))

def find_valleys(smoothed_angles, peaks, search_range=10, min_valley_value=170, min_depth=10):
    valleys = []
    valleys1 = []

    for peak in peaks:
        # 在峰值前後各 `search_range` 幀內找最小值
        left_bound = max(0, peak - search_range)
        right_bound = min(len(smoothed_angles) - 1, peak + search_range)

        # 找到左邊和右邊的波谷
        left_min_index = left_bound + np.argmin(smoothed_angles[left_bound:peak])
        right_min_index = peak + np.argmin(smoothed_angles[peak:right_bound + 1])

        left_min_value = smoothed_angles[left_min_index]
        right_min_value = smoothed_angles[right_min_index]
        peak_value = smoothed_angles[peak]

        # 檢查條件：波谷值小於 170，且谷底夠深 (峰值 - 谷底 >= min_depth)
        if left_min_value < min_valley_value and (peak_value - left_min_value) >= min_depth:
            valleys.append(left_min_index)

        if right_min_value < min_valley_value and (peak_value - right_min_value) >= min_depth:
            valleys1.append(right_min_index)

    return valleys, valleys1

def read_yolo_data(yolo_file):
    """ 讀取 yolo_coordinates_interpolated.txt，回傳 {frame: x} 字典 """
    yolo_data = {}
    with open(yolo_file, 'r') as file:
        for line in file:
            values = line.strip().split(',')
            if len(values) < 3:
                continue
            try:
                frame = int(values[0])
                x_value = float(values[2])  # 第三個數值是 X 座標
                yolo_data[frame] = x_value
            except ValueError:
                continue
    return yolo_data

def split_video(video_path, output_folder, valleys, valleys1, yolo_file, fps=30):
    """
    根據 valleys (黃色谷底) 和 valleys1 (綠色谷底) 分割影片，
    **只存 X 座標變化超過 20 的影片**，如果變化 <= 20，則不存成影片。
    """
    print(123)
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)

    # 讀取影片
    cap = cv2.VideoCapture(video_path)
    total_frames = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
    width, height = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH)), int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
    fourcc = cv2.VideoWriter_fourcc(*'mp4v')  # MP4 格式

    # 讀取 yolo 數據
    yolo_data = read_yolo_data(yolo_file)

    for i, (start_frame, end_frame) in enumerate(zip(valleys, valleys1)):
        if start_frame >= end_frame or start_frame >= total_frames or end_frame >= total_frames:
            print(f"跳過無效範圍: 開始 {start_frame}, 結束 {end_frame}")
            continue

        # 取得該範圍內的 yolo X 值變化
        x_values = [yolo_data[f] for f in range(start_frame, end_frame + 1) if f in yolo_data]
        x_range = max(x_values) - min(x_values) if x_values else 0

        # **如果變化小於等於 20，則跳過該片段**
        if x_range <= 150 or np.isnan(x_range):
            print(f"跳過片段 {i+1}（X 變化範圍: {x_range:.2f}，過小）")
            continue

        # 存影片
        output_path = os.path.join(output_folder, f"clip_{i+1}.mp4")
        out = cv2.VideoWriter(output_path, fourcc, fps, (width, height))
        cap.set(cv2.CAP_PROP_POS_FRAMES, start_frame)

        for frame_idx in range(start_frame, end_frame + 1):
            ret, frame = cap.read()
            if not ret:
                break
            out.write(frame)

        out.release()
        print(f"影片儲存: {output_path}（X 變化範圍: {x_range:.2f}）")

    cap.release()
    print("所有片段處理完成！")


def split_skeleton_data(original_skeleton_path, output_folder, valleys, valleys1, yolo_file):
    """
    根據 valleys (黃色谷底) 和 valleys1 (綠色谷底) 分割骨架數據，
    **只存 X 座標變化超過 20 的片段**，如果變化 <= 20，則不存。
    """
    # 讀取骨架數據檔案
    with open(original_skeleton_path, 'r') as file:
        lines = file.readlines()

    # 讀取 yolo 數據
    yolo_data = read_yolo_data(yolo_file)

    for i, (start_frame, end_frame) in enumerate(zip(valleys, valleys1)):
        if start_frame >= end_frame:
            print(f"跳過無效範圍: 開始 {start_frame}, 結束 {end_frame}")
            continue

        # 計算該片段內的 X 座標變化範圍
        x_values = [yolo_data[f] for f in range(start_frame, end_frame + 1) if f in yolo_data]
        x_range = max(x_values) - min(x_values) if x_values else 0

        # **如果變化小於等於 20，則跳過該片段**
        if x_range <= 150 or np.isnan(x_range):
            print(f"跳過骨架數據 {i+1}（X 變化範圍: {x_range:.2f}，過小）")
            continue

        # 存骨架數據
        clip_folder = os.path.join(output_folder)
        os.makedirs(clip_folder, exist_ok=True)

        output_skeleton_path = os.path.join(clip_folder, f"skeleton_{i+1}.txt")
        with open(output_skeleton_path, 'w') as out_file:
            for line in lines:
                values = line.strip().split(',')
                if len(values) < 4:
                    continue
                try:
                    frame = int(values[0])  # 解析 frame 數
                    if start_frame <= frame <= end_frame:
                        out_file.write(line)  # 保留符合範圍的行
                except ValueError:
                    continue

        print(f"骨架數據儲存: {output_skeleton_path}（Y 變化範圍: {x_range:.2f}）")

    print("所有骨架數據處理完成！")


def split_bar_data(original_bar_path, output_folder, valleys, valleys1, yolo_file):
    """
    根據 valleys (黃色谷底) 和 valleys1 (綠色谷底) 分割槓鈴數據，
    **只存 X 座標變化超過 20 的片段**，如果變化 ≤ 20，則不存。
    """
    # 讀取槓鈴數據檔案
    with open(original_bar_path, 'r') as file:
        lines = file.readlines()

    # 讀取 yolo 數據
    yolo_data = read_yolo_data(yolo_file)

    for i, (start_frame, end_frame) in enumerate(zip(valleys, valleys1)):
        if start_frame >= end_frame:
            print(f"跳過無效範圍: 開始 {start_frame}, 結束 {end_frame}")
            continue

        # 計算該片段內的 X 座標變化範圍
        x_values = [yolo_data[f] for f in range(start_frame, end_frame + 1) if f in yolo_data]
        x_range = max(x_values) - min(x_values) if x_values else 0

        # **如果變化小於等於 20，則跳過該片段**
        if x_range <= 150 or np.isnan(x_range):
            print(f"跳過槓鈴數據 {i+1}（X 變化範圍: {x_range:.2f}，過小）")
            continue

        # 存槓鈴數據
        clip_folder = os.path.join(output_folder)
        os.makedirs(clip_folder, exist_ok=True)

        output_bar_path = os.path.join(clip_folder, f"bar_{i+1}.txt")
        with open(output_bar_path, 'w') as out_file:
            for line in lines:
                values = line.strip().split(',')
                if len(values) < 4:
                    continue
                try:
                    frame = int(values[0])  # 解析 frame 數
                    if start_frame <= frame <= end_frame:
                        out_file.write(line)  # 保留符合範圍的行
                except ValueError:
                    continue

        print(f"槓鈴數據儲存: {output_bar_path}（X 變化範圍: {x_range:.2f}）")

    print("所有槓鈴數據處理完成！")
    

        
def plot_metrics_in_tkinter(yolo_file):
    global root, canvas, valleys, valleys1

    # Tkinter UI 初始化
    root = tk.Tk()
    root.title("Left Knee Angle & Bar Y-Axis Analysis")
    root.geometry("1000x800")

    # 圖表初始化
    fig, axes = Figure(figsize=(10, 8), dpi=100), [None, None, None]
    axes[0] = fig.add_subplot(3, 1, 1)  # 原始角度圖
    axes[1] = fig.add_subplot(3, 1, 2)  # 平滑後角度圖
    axes[2] = fig.add_subplot(3, 1, 3)  # 槓鈴Y座標圖

    # 過濾角度資料中的 None
    valid_frames = [frames[i] for i in range(len(left_knee_angles)) if left_knee_angles[i] is not None]
    valid_angles = np.array([angle for angle in left_knee_angles if angle is not None])

    # 平滑化角度
    smoothed_angles = savgol_filter(valid_angles, window_length=11, polyorder=3)
    peaks, _ = find_peaks(smoothed_angles, height=160, distance=55, prominence=5)

    # 波谷檢測
    all_valleys, all_valleys1 = find_valleys(smoothed_angles, peaks, search_range=90, min_valley_value=170, min_depth=10)

    valleys, valleys1 = [], []
    last_start, last_end = -1, -1  # 初始化前一段範圍
    
    for peak in peaks:
        left_valley = next((v for v in reversed(all_valleys) if v < peak), None)
        right_valley = next((v for v in all_valleys1 if v > peak), None)
    
        if left_valley is not None and right_valley is not None:
            new_start, new_end = left_valley, right_valley
    
            # 檢查是否和上一段有超過 50% 重疊
            if last_start != -1 and last_end != -1:
                overlap_start = max(new_start, last_start)
                overlap_end = min(new_end, last_end)
                overlap = max(0, overlap_end - overlap_start)
                len_last = last_end - last_start
                len_new = new_end - new_start
    
                if overlap / min(len_last, len_new) > 0.5:
                    print(f"跳過重疊片段：({new_start}, {new_end}) 和上一段重疊 {overlap} 幀")
                    continue  # 跳過這個片段
    
            valleys.append(new_start)
            valleys1.append(new_end)
            last_start, last_end = new_start, new_end  # 更新上一段範圍


    


    # === [1] 原始角度圖 ===
    axes[0].plot(valid_frames, valid_angles, color='gray', alpha=0.7)
    axes[0].plot(np.array(valid_frames)[peaks], valid_angles[peaks], 'ro')
    axes[0].plot(np.array(valid_frames)[valleys], valid_angles[valleys], 'yo')
    axes[0].plot(np.array(valid_frames)[valleys1], valid_angles[valleys1], 'go')
    axes[0].set_title("Raw Left Knee Angle")
    axes[0].set_ylabel("Angle (deg)")
    axes[0].grid()

    # === [2] 平滑角度圖 ===
    axes[1].plot(valid_frames, smoothed_angles, color='blue')
    axes[1].plot(np.array(valid_frames)[peaks], smoothed_angles[peaks], 'ro')
    axes[1].plot(np.array(valid_frames)[valleys], smoothed_angles[valleys], 'yo')
    axes[1].plot(np.array(valid_frames)[valleys1], smoothed_angles[valleys1], 'go')
    axes[1].set_title("Smoothed Left Knee Angle")
    axes[1].set_ylabel("Angle (deg)")
    axes[1].grid()

    # === [3] 槓鈴Y座標變化圖 ===
    yolo_data = read_yolo_data(yolo_file)
    bar_y_frames = sorted(yolo_data.keys())
    bar_y_values = [yolo_data[frame] for frame in bar_y_frames]

    axes[2].plot(bar_y_frames, bar_y_values, color='purple', label='Bar Y-axis')
    axes[2].set_title("Barbell Y-Coordinate Over Time")
    axes[2].set_xlabel("Frame")
    axes[2].set_ylabel("Y Position")
    axes[2].grid()

    
    # 標記左右谷底區間
    # 僅標記被實際儲存的片段（X 變化範圍 > 50）
    for v_start, v_end in zip(valleys, valleys1):
        x_values = [yolo_data[f] for f in range(valid_frames[v_start], valid_frames[v_end] + 1) if f in yolo_data]
        x_range = max(x_values) - min(x_values) if x_values else 0
    
        if x_range > 150:
            axes[2].axvspan(valid_frames[v_start], valid_frames[v_end], color='yellow', alpha=0.2)




    # === 儲存圖像 ===



    print(valleys, valleys1)
    fig.savefig(path+"\\left_knee_angle_plot.png")  # 儲存為 PNG 圖檔
    print(path+"\\left_knee_angle_plot.png")
    canvas = FigureCanvasTkAgg(fig, root)
    canvas.get_tk_widget().pack(fill=tk.BOTH, expand=True)
    # root.mainloop()

    
# path = "D:/labdata/MOCAP/recordings_copy/受試者11/recording_20241204_112324/"
# # 設定你的檔案路徑
# skeleton_file_path = os.path.join(path, f'yolo_skeleton_coordinates_1st_interp.txt')
# # 設定影片路徑
# video_path =  os.path.join(path, f'vision1.avi')
# output_folder = os.path.join(path, f'clips')
# output_folder1 = os.path.join(path, f'skeleton')
# # 讀取數據
# skeleton_data = read_skeleton_data(skeleton_file_path)
# frames, left_knee_angles = calculate_angles(skeleton_data)
# plot_metrics_in_tkinter()
# split_skeleton_data(skeleton_file_path,output_folder1,valleys,valleys1)

# for i in range(15):
#     base_path = f"D:/labdata/MOCAP/recordings_copy/受試者{56+i}"+"/"

base_path = "D:/labdata/MOCAP/recordings_copy/"
# 取得 base_path 下的所有子資料夾
for sub_folder in os.listdir(base_path):
    midpath = os.path.join(base_path, sub_folder)
    
    # 確保 path 是資料夾
    if not os.path.isdir(midpath):
        continue

    for sub_folder1 in os.listdir(midpath):
        path = os.path.join(midpath, sub_folder1)
        
        # 確保 path 是資料夾
        if not os.path.isdir(path):
            continue
    
    
        # 設定檔案路徑
        skeleton_file_path = os.path.join(path, 'yolo_skeleton_coordinates_vision1_interp.txt')
        bar_file_path = os.path.join(path, 'yolo_coordinates_interpolated.txt')
        video_path = os.path.join(path, 'vision1.avi')
        output_folder = os.path.join(path, 'clips')
        output_folder1 = os.path.join(path, 'skeleton_vision1')
    
        output_folder2 = os.path.join(path, 'bar')
    
        # 檢查檔案是否存在，避免錯誤
        if not os.path.exists(skeleton_file_path):
            print(f"檔案 {skeleton_file_path} 不存在，跳過該資料夾")
            continue
    
    #         讀取數據
        skeleton_data = read_skeleton_data(skeleton_file_pat-h)
        frames, left_knee_angles = calculate_angles(skeleton_data)
    
        # 顯示波形圖
        plot_metrics_in_tkinter(bar_file_path)
        # split_video(video_path, output_folder, valleys, valleys1,bar_file_path, fps=30)
        # # 執行切割
        split_skeleton_data(skeleton_file_path, output_folder1, valleys, valleys1,bar_file_path)
        # split_bar_data(bar_file_path, output_folder2, valleys, valleys1,bar_file_path)
# Out:
# 檔案 D:/labdata/MOCAP/recordings_copy/受試者10\recording_20241204_094919棋盤\yolo_skeleton_coordinates_vision1_interp.txt 不存在，跳過該資料夾
# [37, 108, 205, 279, 371, 443, 544, 623, 679, 753] [108, 205, 279, 371, 443, 544, 623, 679, 753, 908]
# D:/labdata/MOCAP/recordings_copy/受試者10\recording_20241204_100047\left_knee_angle_plot.png
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者10\recording_20241204_100047\skeleton_vision1\skeleton_1.txt（Y 變化範圍: 309.94）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者10\recording_20241204_100047\skeleton_vision1\skeleton_2.txt（Y 變化範圍: 266.07）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者10\recording_20241204_100047\skeleton_vision1\skeleton_3.txt（Y 變化範圍: 287.26）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者10\recording_20241204_100047\skeleton_vision1\skeleton_4.txt（Y 變化範圍: 261.01）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者10\recording_20241204_100047\skeleton_vision1\skeleton_5.txt（Y 變化範圍: 254.28）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者10\recording_20241204_100047\skeleton_vision1\skeleton_6.txt（Y 變化範圍: 262.83）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者10\recording_20241204_100047\skeleton_vision1\skeleton_7.txt（Y 變化範圍: 247.94）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者10\recording_20241204_100047\skeleton_vision1\skeleton_8.txt（Y 變化範圍: 235.45）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者10\recording_20241204_100047\skeleton_vision1\skeleton_9.txt（Y 變化範圍: 266.85）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者10\recording_20241204_100047\skeleton_vision1\skeleton_10.txt（Y 變化範圍: 298.04）
# 所有骨架數據處理完成！
# [68, 146, 233, 317, 410, 501, 600, 675, 756, 837, 923, 1009] [146, 233, 317, 410, 501, 600, 675, 756, 837, 923, 1009, 1108]
# D:/labdata/MOCAP/recordings_copy/受試者10\recording_20241204_100314\left_knee_angle_plot.png
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者10\recording_20241204_100314\skeleton_vision1\skeleton_1.txt（Y 變化範圍: 370.51）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者10\recording_20241204_100314\skeleton_vision1\skeleton_2.txt（Y 變化範圍: 370.34）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者10\recording_20241204_100314\skeleton_vision1\skeleton_3.txt（Y 變化範圍: 348.92）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者10\recording_20241204_100314\skeleton_vision1\skeleton_4.txt（Y 變化範圍: 356.58）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者10\recording_20241204_100314\skeleton_vision1\skeleton_5.txt（Y 變化範圍: 331.84）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者10\recording_20241204_100314\skeleton_vision1\skeleton_6.txt（Y 變化範圍: 336.81）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者10\recording_20241204_100314\skeleton_vision1\skeleton_7.txt（Y 變化範圍: 354.16）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者10\recording_20241204_100314\skeleton_vision1\skeleton_8.txt（Y 變化範圍: 347.75）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者10\recording_20241204_100314\skeleton_vision1\skeleton_9.txt（Y 變化範圍: 356.64）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者10\recording_20241204_100314\skeleton_vision1\skeleton_10.txt（Y 變化範圍: 326.81）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者10\recording_20241204_100314\skeleton_vision1\skeleton_11.txt（Y 變化範圍: 341.32）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者10\recording_20241204_100314\skeleton_vision1\skeleton_12.txt（Y 變化範圍: 359.32）
# 所有骨架數據處理完成！
# [27, 125, 224, 315, 399, 489, 585, 675, 763, 851, 933, 1018, 1088, 1175, 1257, 1343, 1420] [125, 224, 315, 399, 489, 585, 675, 763, 851, 933, 1018, 1088, 1175, 1257, 1343, 1420, 1497]
# D:/labdata/MOCAP/recordings_copy/受試者10\recording_20241204_100527\left_knee_angle_plot.png
# 跳過骨架數據 1（X 變化範圍: 0.36，過小）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者10\recording_20241204_100527\skeleton_vision1\skeleton_2.txt（Y 變化範圍: 364.88）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者10\recording_20241204_100527\skeleton_vision1\skeleton_3.txt（Y 變化範圍: 326.36）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者10\recording_20241204_100527\skeleton_vision1\skeleton_4.txt（Y 變化範圍: 333.93）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者10\recording_20241204_100527\skeleton_vision1\skeleton_5.txt（Y 變化範圍: 320.22）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者10\recording_20241204_100527\skeleton_vision1\skeleton_6.txt（Y 變化範圍: 319.51）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者10\recording_20241204_100527\skeleton_vision1\skeleton_7.txt（Y 變化範圍: 308.37）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者10\recording_20241204_100527\skeleton_vision1\skeleton_8.txt（Y 變化範圍: 307.17）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者10\recording_20241204_100527\skeleton_vision1\skeleton_9.txt（Y 變化範圍: 316.39）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者10\recording_20241204_100527\skeleton_vision1\skeleton_10.txt（Y 變化範圍: 312.10）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者10\recording_20241204_100527\skeleton_vision1\skeleton_11.txt（Y 變化範圍: 303.72）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者10\recording_20241204_100527\skeleton_vision1\skeleton_12.txt（Y 變化範圍: 299.51）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者10\recording_20241204_100527\skeleton_vision1\skeleton_13.txt（Y 變化範圍: 309.56）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者10\recording_20241204_100527\skeleton_vision1\skeleton_14.txt（Y 變化範圍: 305.73）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者10\recording_20241204_100527\skeleton_vision1\skeleton_15.txt（Y 變化範圍: 294.30）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者10\recording_20241204_100527\skeleton_vision1\skeleton_16.txt（Y 變化範圍: 301.23）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者10\recording_20241204_100527\skeleton_vision1\skeleton_17.txt（Y 變化範圍: 298.80）
# 所有骨架數據處理完成！
# [38, 153, 252, 370, 482, 593, 687, 801, 922, 1034, 1157] [153, 252, 370, 482, 593, 687, 801, 922, 1034, 1157, 1262]
# D:/labdata/MOCAP/recordings_copy/受試者10\recording_20241204_101023\left_knee_angle_plot.png
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者10\recording_20241204_101023\skeleton_vision1\skeleton_1.txt（Y 變化範圍: 370.17）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者10\recording_20241204_101023\skeleton_vision1\skeleton_2.txt（Y 變化範圍: 374.74）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者10\recording_20241204_101023\skeleton_vision1\skeleton_3.txt（Y 變化範圍: 333.57）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者10\recording_20241204_101023\skeleton_vision1\skeleton_4.txt（Y 變化範圍: 346.24）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者10\recording_20241204_101023\skeleton_vision1\skeleton_5.txt（Y 變化範圍: 340.47）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者10\recording_20241204_101023\skeleton_vision1\skeleton_6.txt（Y 變化範圍: 348.77）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者10\recording_20241204_101023\skeleton_vision1\skeleton_7.txt（Y 變化範圍: 358.05）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者10\recording_20241204_101023\skeleton_vision1\skeleton_8.txt（Y 變化範圍: 331.42）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者10\recording_20241204_101023\skeleton_vision1\skeleton_9.txt（Y 變化範圍: 344.39）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者10\recording_20241204_101023\skeleton_vision1\skeleton_10.txt（Y 變化範圍: 343.87）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者10\recording_20241204_101023\skeleton_vision1\skeleton_11.txt（Y 變化範圍: 340.24）
# 所有骨架數據處理完成！
# [65, 160, 253, 353, 442, 530, 634, 692, 786, 872] [160, 253, 353, 442, 530, 634, 692, 786, 872, 975]
# D:/labdata/MOCAP/recordings_copy/受試者10\recording_20241204_101150\left_knee_angle_plot.png
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者10\recording_20241204_101150\skeleton_vision1\skeleton_1.txt（Y 變化範圍: 342.59）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者10\recording_20241204_101150\skeleton_vision1\skeleton_2.txt（Y 變化範圍: 330.66）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者10\recording_20241204_101150\skeleton_vision1\skeleton_3.txt（Y 變化範圍: 376.66）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者10\recording_20241204_101150\skeleton_vision1\skeleton_4.txt（Y 變化範圍: 338.11）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者10\recording_20241204_101150\skeleton_vision1\skeleton_5.txt（Y 變化範圍: 335.75）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者10\recording_20241204_101150\skeleton_vision1\skeleton_6.txt（Y 變化範圍: 318.52）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者10\recording_20241204_101150\skeleton_vision1\skeleton_7.txt（Y 變化範圍: 323.35）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者10\recording_20241204_101150\skeleton_vision1\skeleton_8.txt（Y 變化範圍: 329.07）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者10\recording_20241204_101150\skeleton_vision1\skeleton_9.txt（Y 變化範圍: 328.97）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者10\recording_20241204_101150\skeleton_vision1\skeleton_10.txt（Y 變化範圍: 349.96）
# 所有骨架數據處理完成！
# 檔案 D:/labdata/MOCAP/recordings_copy/受試者100\recording_20250117_100000 棋盤\yolo_skeleton_coordinates_vision1_interp.txt 不存在，跳過該資料夾
# [128, 273, 353, 470, 567, 657, 744, 834, 916, 1019] [273, 353, 470, 567, 657, 744, 834, 916, 1019, 1095]
# D:/labdata/MOCAP/recordings_copy/受試者100\recording_20250117_101537\left_knee_angle_plot.png
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者100\recording_20250117_101537\skeleton_vision1\skeleton_1.txt（Y 變化範圍: 306.29）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者100\recording_20250117_101537\skeleton_vision1\skeleton_2.txt（Y 變化範圍: 332.62）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者100\recording_20250117_101537\skeleton_vision1\skeleton_3.txt（Y 變化範圍: 345.93）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者100\recording_20250117_101537\skeleton_vision1\skeleton_4.txt（Y 變化範圍: 351.46）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者100\recording_20250117_101537\skeleton_vision1\skeleton_5.txt（Y 變化範圍: 340.99）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者100\recording_20250117_101537\skeleton_vision1\skeleton_6.txt（Y 變化範圍: 359.48）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者100\recording_20250117_101537\skeleton_vision1\skeleton_7.txt（Y 變化範圍: 333.20）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者100\recording_20250117_101537\skeleton_vision1\skeleton_8.txt（Y 變化範圍: 338.12）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者100\recording_20250117_101537\skeleton_vision1\skeleton_9.txt（Y 變化範圍: 335.20）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者100\recording_20250117_101537\skeleton_vision1\skeleton_10.txt（Y 變化範圍: 332.38）
# 所有骨架數據處理完成！
# [65, 167, 254, 337, 444, 536, 631, 724, 813, 901] [167, 254, 337, 444, 536, 631, 724, 813, 901, 977]
# D:/labdata/MOCAP/recordings_copy/受試者100\recording_20250117_101653\left_knee_angle_plot.png
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者100\recording_20250117_101653\skeleton_vision1\skeleton_1.txt（Y 變化範圍: 346.53）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者100\recording_20250117_101653\skeleton_vision1\skeleton_2.txt（Y 變化範圍: 348.99）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者100\recording_20250117_101653\skeleton_vision1\skeleton_3.txt（Y 變化範圍: 381.67）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者100\recording_20250117_101653\skeleton_vision1\skeleton_4.txt（Y 變化範圍: 381.99）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者100\recording_20250117_101653\skeleton_vision1\skeleton_5.txt（Y 變化範圍: 377.16）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者100\recording_20250117_101653\skeleton_vision1\skeleton_6.txt（Y 變化範圍: 358.76）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者100\recording_20250117_101653\skeleton_vision1\skeleton_7.txt（Y 變化範圍: 345.47）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者100\recording_20250117_101653\skeleton_vision1\skeleton_8.txt（Y 變化範圍: 351.13）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者100\recording_20250117_101653\skeleton_vision1\skeleton_9.txt（Y 變化範圍: 392.11）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者100\recording_20250117_101653\skeleton_vision1\skeleton_10.txt（Y 變化範圍: 381.35）
# 所有骨架數據處理完成！
# [47, 179, 352, 482, 600, 761, 895, 1020, 1134, 1293] [179, 304, 482, 600, 761, 895, 1020, 1134, 1292, 1467]
# D:/labdata/MOCAP/recordings_copy/受試者100\recording_20250117_101856\left_knee_angle_plot.png
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者100\recording_20250117_101856\skeleton_vision1\skeleton_1.txt（Y 變化範圍: 330.14）
# 跳過骨架數據 2（X 變化範圍: 24.94，過小）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者100\recording_20250117_101856\skeleton_vision1\skeleton_3.txt（Y 變化範圍: 332.59）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者100\recording_20250117_101856\skeleton_vision1\skeleton_4.txt（Y 變化範圍: 334.74）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者100\recording_20250117_101856\skeleton_vision1\skeleton_5.txt（Y 變化範圍: 334.63）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者100\recording_20250117_101856\skeleton_vision1\skeleton_6.txt（Y 變化範圍: 338.63）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者100\recording_20250117_101856\skeleton_vision1\skeleton_7.txt（Y 變化範圍: 344.35）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者100\recording_20250117_101856\skeleton_vision1\skeleton_8.txt（Y 變化範圍: 295.17）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者100\recording_20250117_101856\skeleton_vision1\skeleton_9.txt（Y 變化範圍: 288.79）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者100\recording_20250117_101856\skeleton_vision1\skeleton_10.txt（Y 變化範圍: 300.44）
# 所有骨架數據處理完成！
# [71, 211, 347, 503, 638, 746, 925, 1084, 1240, 1362] [189, 347, 503, 624, 746, 914, 1059, 1182, 1362, 1477]
# D:/labdata/MOCAP/recordings_copy/受試者100\recording_20250117_102052\left_knee_angle_plot.png
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者100\recording_20250117_102052\skeleton_vision1\skeleton_1.txt（Y 變化範圍: 436.98）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者100\recording_20250117_102052\skeleton_vision1\skeleton_2.txt（Y 變化範圍: 449.53）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者100\recording_20250117_102052\skeleton_vision1\skeleton_3.txt（Y 變化範圍: 430.97）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者100\recording_20250117_102052\skeleton_vision1\skeleton_4.txt（Y 變化範圍: 403.89）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者100\recording_20250117_102052\skeleton_vision1\skeleton_5.txt（Y 變化範圍: 364.38）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者100\recording_20250117_102052\skeleton_vision1\skeleton_6.txt（Y 變化範圍: 368.73）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者100\recording_20250117_102052\skeleton_vision1\skeleton_7.txt（Y 變化範圍: 404.42）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者100\recording_20250117_102052\skeleton_vision1\skeleton_8.txt（Y 變化範圍: 391.28）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者100\recording_20250117_102052\skeleton_vision1\skeleton_9.txt（Y 變化範圍: 375.73）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者100\recording_20250117_102052\skeleton_vision1\skeleton_10.txt（Y 變化範圍: 363.21）
# 所有骨架數據處理完成！
# [0, 50, 197, 347, 486, 645, 743, 882, 992, 1091, 1199] [50, 197, 347, 478, 645, 743, 882, 992, 1091, 1199, 1275]
# D:/labdata/MOCAP/recordings_copy/受試者100\recording_20250117_102424\left_knee_angle_plot.png
# 跳過骨架數據 1（X 變化範圍: 0.31，過小）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者100\recording_20250117_102424\skeleton_vision1\skeleton_2.txt（Y 變化範圍: 353.19）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者100\recording_20250117_102424\skeleton_vision1\skeleton_3.txt（Y 變化範圍: 350.11）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者100\recording_20250117_102424\skeleton_vision1\skeleton_4.txt（Y 變化範圍: 336.64）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者100\recording_20250117_102424\skeleton_vision1\skeleton_5.txt（Y 變化範圍: 305.65）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者100\recording_20250117_102424\skeleton_vision1\skeleton_6.txt（Y 變化範圍: 322.91）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者100\recording_20250117_102424\skeleton_vision1\skeleton_7.txt（Y 變化範圍: 326.46）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者100\recording_20250117_102424\skeleton_vision1\skeleton_8.txt（Y 變化範圍: 334.92）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者100\recording_20250117_102424\skeleton_vision1\skeleton_9.txt（Y 變化範圍: 297.59）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者100\recording_20250117_102424\skeleton_vision1\skeleton_10.txt（Y 變化範圍: 298.62）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者100\recording_20250117_102424\skeleton_vision1\skeleton_11.txt（Y 變化範圍: 307.68）
# 所有骨架數據處理完成！
# 檔案 D:/labdata/MOCAP/recordings_copy/受試者101\recording_20250117_100000 棋盤\yolo_skeleton_coordinates_vision1_interp.txt 不存在，跳過該資料夾
# [63, 221, 363, 510, 655, 787, 924, 1053, 1223, 1410, 1523] [207, 360, 509, 647, 787, 924, 1045, 1170, 1352, 1523, 1632]
# D:/labdata/MOCAP/recordings_copy/受試者101\recording_20250117_160137\left_knee_angle_plot.png
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者101\recording_20250117_160137\skeleton_vision1\skeleton_1.txt（Y 變化範圍: 400.94）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者101\recording_20250117_160137\skeleton_vision1\skeleton_2.txt（Y 變化範圍: 434.05）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者101\recording_20250117_160137\skeleton_vision1\skeleton_3.txt（Y 變化範圍: 434.76）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者101\recording_20250117_160137\skeleton_vision1\skeleton_4.txt（Y 變化範圍: 427.78）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者101\recording_20250117_160137\skeleton_vision1\skeleton_5.txt（Y 變化範圍: 448.80）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者101\recording_20250117_160137\skeleton_vision1\skeleton_6.txt（Y 變化範圍: 437.59）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者101\recording_20250117_160137\skeleton_vision1\skeleton_7.txt（Y 變化範圍: 428.29）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者101\recording_20250117_160137\skeleton_vision1\skeleton_8.txt（Y 變化範圍: 450.75）
# 跳過骨架數據 9（X 變化範圍: 0.89，過小）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者101\recording_20250117_160137\skeleton_vision1\skeleton_10.txt（Y 變化範圍: 415.98）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者101\recording_20250117_160137\skeleton_vision1\skeleton_11.txt（Y 變化範圍: 419.71）
# 所有骨架數據處理完成！
# [76, 180, 289, 388, 493, 588, 672, 793, 875, 980, 1083] [180, 289, 388, 493, 588, 672, 793, 875, 980, 1083, 1129]
# D:/labdata/MOCAP/recordings_copy/受試者101\recording_20250117_160416\left_knee_angle_plot.png
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者101\recording_20250117_160416\skeleton_vision1\skeleton_1.txt（Y 變化範圍: 408.81）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者101\recording_20250117_160416\skeleton_vision1\skeleton_2.txt（Y 變化範圍: 431.76）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者101\recording_20250117_160416\skeleton_vision1\skeleton_3.txt（Y 變化範圍: 437.09）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者101\recording_20250117_160416\skeleton_vision1\skeleton_4.txt（Y 變化範圍: 432.33）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者101\recording_20250117_160416\skeleton_vision1\skeleton_5.txt（Y 變化範圍: 428.73）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者101\recording_20250117_160416\skeleton_vision1\skeleton_6.txt（Y 變化範圍: 437.07）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者101\recording_20250117_160416\skeleton_vision1\skeleton_7.txt（Y 變化範圍: 418.40）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者101\recording_20250117_160416\skeleton_vision1\skeleton_8.txt（Y 變化範圍: 434.57）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者101\recording_20250117_160416\skeleton_vision1\skeleton_9.txt（Y 變化範圍: 455.56）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者101\recording_20250117_160416\skeleton_vision1\skeleton_10.txt（Y 變化範圍: 451.59）
# 跳過骨架數據 11（X 變化範圍: 3.25，過小）
# 所有骨架數據處理完成！
# [172, 317, 431, 554, 676, 783, 904, 1040, 1157, 1282] [317, 431, 554, 676, 783, 904, 1040, 1157, 1280, 1369]
# D:/labdata/MOCAP/recordings_copy/受試者101\recording_20250117_160602\left_knee_angle_plot.png
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者101\recording_20250117_160602\skeleton_vision1\skeleton_1.txt（Y 變化範圍: 424.50）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者101\recording_20250117_160602\skeleton_vision1\skeleton_2.txt（Y 變化範圍: 444.96）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者101\recording_20250117_160602\skeleton_vision1\skeleton_3.txt（Y 變化範圍: 428.21）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者101\recording_20250117_160602\skeleton_vision1\skeleton_4.txt（Y 變化範圍: 437.84）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者101\recording_20250117_160602\skeleton_vision1\skeleton_5.txt（Y 變化範圍: 427.41）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者101\recording_20250117_160602\skeleton_vision1\skeleton_6.txt（Y 變化範圍: 424.92）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者101\recording_20250117_160602\skeleton_vision1\skeleton_7.txt（Y 變化範圍: 427.54）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者101\recording_20250117_160602\skeleton_vision1\skeleton_8.txt（Y 變化範圍: 431.68）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者101\recording_20250117_160602\skeleton_vision1\skeleton_9.txt（Y 變化範圍: 428.88）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者101\recording_20250117_160602\skeleton_vision1\skeleton_10.txt（Y 變化範圍: 436.68）
# 所有骨架數據處理完成！
# [42, 168, 318, 434, 545, 680, 812, 922, 1050, 1180] [168, 318, 434, 545, 680, 812, 922, 1050, 1180, 1269]
# D:/labdata/MOCAP/recordings_copy/受試者101\recording_20250117_161050\left_knee_angle_plot.png
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者101\recording_20250117_161050\skeleton_vision1\skeleton_1.txt（Y 變化範圍: 387.62）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者101\recording_20250117_161050\skeleton_vision1\skeleton_2.txt（Y 變化範圍: 393.16）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者101\recording_20250117_161050\skeleton_vision1\skeleton_3.txt（Y 變化範圍: 412.23）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者101\recording_20250117_161050\skeleton_vision1\skeleton_4.txt（Y 變化範圍: 402.20）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者101\recording_20250117_161050\skeleton_vision1\skeleton_5.txt（Y 變化範圍: 400.76）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者101\recording_20250117_161050\skeleton_vision1\skeleton_6.txt（Y 變化範圍: 402.84）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者101\recording_20250117_161050\skeleton_vision1\skeleton_7.txt（Y 變化範圍: 418.43）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者101\recording_20250117_161050\skeleton_vision1\skeleton_8.txt（Y 變化範圍: 411.32）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者101\recording_20250117_161050\skeleton_vision1\skeleton_9.txt（Y 變化範圍: 422.74）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者101\recording_20250117_161050\skeleton_vision1\skeleton_10.txt（Y 變化範圍: 405.37）
# 所有骨架數據處理完成！
# [0, 127, 250, 371, 488, 621, 727, 852, 976, 1082] [127, 250, 371, 488, 621, 727, 852, 976, 1082, 1196]
# D:/labdata/MOCAP/recordings_copy/受試者101\recording_20250117_161316\left_knee_angle_plot.png
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者101\recording_20250117_161316\skeleton_vision1\skeleton_1.txt（Y 變化範圍: 434.93）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者101\recording_20250117_161316\skeleton_vision1\skeleton_2.txt（Y 變化範圍: 447.30）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者101\recording_20250117_161316\skeleton_vision1\skeleton_3.txt（Y 變化範圍: 437.33）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者101\recording_20250117_161316\skeleton_vision1\skeleton_4.txt（Y 變化範圍: 431.91）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者101\recording_20250117_161316\skeleton_vision1\skeleton_5.txt（Y 變化範圍: 410.58）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者101\recording_20250117_161316\skeleton_vision1\skeleton_6.txt（Y 變化範圍: 418.35）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者101\recording_20250117_161316\skeleton_vision1\skeleton_7.txt（Y 變化範圍: 410.03）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者101\recording_20250117_161316\skeleton_vision1\skeleton_8.txt（Y 變化範圍: 408.88）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者101\recording_20250117_161316\skeleton_vision1\skeleton_9.txt（Y 變化範圍: 399.31）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者101\recording_20250117_161316\skeleton_vision1\skeleton_10.txt（Y 變化範圍: 416.69）
# 所有骨架數據處理完成！
# 檔案 D:/labdata/MOCAP/recordings_copy/受試者102\recording_20250117_100000 棋盤\yolo_skeleton_coordinates_vision1_interp.txt 不存在，跳過該資料夾
# [52, 154, 245, 361, 446, 577, 659, 777, 875] [154, 245, 361, 446, 577, 659, 777, 875, 1001]
# D:/labdata/MOCAP/recordings_copy/受試者102\recording_20250117_160256\left_knee_angle_plot.png
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者102\recording_20250117_160256\skeleton_vision1\skeleton_1.txt（Y 變化範圍: 419.98）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者102\recording_20250117_160256\skeleton_vision1\skeleton_2.txt（Y 變化範圍: 400.04）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者102\recording_20250117_160256\skeleton_vision1\skeleton_3.txt（Y 變化範圍: 419.67）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者102\recording_20250117_160256\skeleton_vision1\skeleton_4.txt（Y 變化範圍: 410.50）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者102\recording_20250117_160256\skeleton_vision1\skeleton_5.txt（Y 變化範圍: 402.73）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者102\recording_20250117_160256\skeleton_vision1\skeleton_6.txt（Y 變化範圍: 412.94）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者102\recording_20250117_160256\skeleton_vision1\skeleton_7.txt（Y 變化範圍: 394.40）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者102\recording_20250117_160256\skeleton_vision1\skeleton_8.txt（Y 變化範圍: 386.67）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者102\recording_20250117_160256\skeleton_vision1\skeleton_9.txt（Y 變化範圍: 389.30）
# 所有骨架數據處理完成！
# [6, 114, 216, 319, 414, 516, 613, 719, 807, 886] [114, 216, 319, 414, 516, 613, 719, 807, 886, 981]
# D:/labdata/MOCAP/recordings_copy/受試者102\recording_20250117_160506\left_knee_angle_plot.png
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者102\recording_20250117_160506\skeleton_vision1\skeleton_1.txt（Y 變化範圍: 411.08）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者102\recording_20250117_160506\skeleton_vision1\skeleton_2.txt（Y 變化範圍: 413.68）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者102\recording_20250117_160506\skeleton_vision1\skeleton_3.txt（Y 變化範圍: 395.95）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者102\recording_20250117_160506\skeleton_vision1\skeleton_4.txt（Y 變化範圍: 398.84）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者102\recording_20250117_160506\skeleton_vision1\skeleton_5.txt（Y 變化範圍: 418.96）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者102\recording_20250117_160506\skeleton_vision1\skeleton_6.txt（Y 變化範圍: 423.89）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者102\recording_20250117_160506\skeleton_vision1\skeleton_7.txt（Y 變化範圍: 414.43）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者102\recording_20250117_160506\skeleton_vision1\skeleton_8.txt（Y 變化範圍: 400.61）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者102\recording_20250117_160506\skeleton_vision1\skeleton_9.txt（Y 變化範圍: 400.02）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者102\recording_20250117_160506\skeleton_vision1\skeleton_10.txt（Y 變化範圍: 425.75）
# 所有骨架數據處理完成！
# [0, 110, 250, 404, 505, 605, 689, 795, 896, 1004] [110, 250, 401, 505, 605, 689, 795, 896, 1004, 1083]
# D:/labdata/MOCAP/recordings_copy/受試者102\recording_20250117_160659\left_knee_angle_plot.png
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者102\recording_20250117_160659\skeleton_vision1\skeleton_1.txt（Y 變化範圍: 409.26）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者102\recording_20250117_160659\skeleton_vision1\skeleton_2.txt（Y 變化範圍: 439.43）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者102\recording_20250117_160659\skeleton_vision1\skeleton_3.txt（Y 變化範圍: 497.52）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者102\recording_20250117_160659\skeleton_vision1\skeleton_4.txt（Y 變化範圍: 458.35）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者102\recording_20250117_160659\skeleton_vision1\skeleton_5.txt（Y 變化範圍: 440.17）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者102\recording_20250117_160659\skeleton_vision1\skeleton_6.txt（Y 變化範圍: 452.92）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者102\recording_20250117_160659\skeleton_vision1\skeleton_7.txt（Y 變化範圍: 404.47）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者102\recording_20250117_160659\skeleton_vision1\skeleton_8.txt（Y 變化範圍: 432.48）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者102\recording_20250117_160659\skeleton_vision1\skeleton_9.txt（Y 變化範圍: 414.00）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者102\recording_20250117_160659\skeleton_vision1\skeleton_10.txt（Y 變化範圍: 409.34）
# 所有骨架數據處理完成！
# [13, 112, 221, 315, 401, 501, 600, 709, 805, 898] [112, 221, 315, 401, 501, 600, 709, 805, 898, 966]
# D:/labdata/MOCAP/recordings_copy/受試者102\recording_20250117_161211\left_knee_angle_plot.png
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者102\recording_20250117_161211\skeleton_vision1\skeleton_1.txt（Y 變化範圍: 398.58）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者102\recording_20250117_161211\skeleton_vision1\skeleton_2.txt（Y 變化範圍: 418.33）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者102\recording_20250117_161211\skeleton_vision1\skeleton_3.txt（Y 變化範圍: 414.89）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者102\recording_20250117_161211\skeleton_vision1\skeleton_4.txt（Y 變化範圍: 419.40）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者102\recording_20250117_161211\skeleton_vision1\skeleton_5.txt（Y 變化範圍: 425.25）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者102\recording_20250117_161211\skeleton_vision1\skeleton_6.txt（Y 變化範圍: 413.59）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者102\recording_20250117_161211\skeleton_vision1\skeleton_7.txt（Y 變化範圍: 404.81）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者102\recording_20250117_161211\skeleton_vision1\skeleton_8.txt（Y 變化範圍: 420.92）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者102\recording_20250117_161211\skeleton_vision1\skeleton_9.txt（Y 變化範圍: 393.32）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者102\recording_20250117_161211\skeleton_vision1\skeleton_10.txt（Y 變化範圍: 406.87）
# 所有骨架數據處理完成！
# [49, 156, 241, 377, 482, 580, 695, 771, 874, 1009] [156, 241, 377, 482, 580, 695, 771, 874, 1009, 1073]
# D:/labdata/MOCAP/recordings_copy/受試者102\recording_20250117_161409\left_knee_angle_plot.png
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者102\recording_20250117_161409\skeleton_vision1\skeleton_1.txt（Y 變化範圍: 355.52）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者102\recording_20250117_161409\skeleton_vision1\skeleton_2.txt（Y 變化範圍: 394.13）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者102\recording_20250117_161409\skeleton_vision1\skeleton_3.txt（Y 變化範圍: 420.18）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者102\recording_20250117_161409\skeleton_vision1\skeleton_4.txt（Y 變化範圍: 402.77）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者102\recording_20250117_161409\skeleton_vision1\skeleton_5.txt（Y 變化範圍: 392.26）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者102\recording_20250117_161409\skeleton_vision1\skeleton_6.txt（Y 變化範圍: 407.89）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者102\recording_20250117_161409\skeleton_vision1\skeleton_7.txt（Y 變化範圍: 393.40）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者102\recording_20250117_161409\skeleton_vision1\skeleton_8.txt（Y 變化範圍: 392.37）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者102\recording_20250117_161409\skeleton_vision1\skeleton_9.txt（Y 變化範圍: 417.17）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者102\recording_20250117_161409\skeleton_vision1\skeleton_10.txt（Y 變化範圍: 406.86）
# 所有骨架數據處理完成！
# 檔案 D:/labdata/MOCAP/recordings_copy/受試者103\recording_20250214_114019\yolo_skeleton_coordinates_vision1_interp.txt 不存在，跳過該資料夾
# 檔案 D:/labdata/MOCAP/recordings_copy/受試者103\recording_20250214_114525\yolo_skeleton_coordinates_vision1_interp.txt 不存在，跳過該資料夾
# 檔案 D:/labdata/MOCAP/recordings_copy/受試者103\recording_20250214_115156\yolo_skeleton_coordinates_vision1_interp.txt 不存在，跳過該資料夾
# 檔案 D:/labdata/MOCAP/recordings_copy/受試者103\recording_20250214_115610\yolo_skeleton_coordinates_vision1_interp.txt 不存在，跳過該資料夾
# 檔案 D:/labdata/MOCAP/recordings_copy/受試者103\recording_20250214_120023\yolo_skeleton_coordinates_vision1_interp.txt 不存在，跳過該資料夾
# 檔案 D:/labdata/MOCAP/recordings_copy/受試者103\recording_20250214_123313_棋盤\yolo_skeleton_coordinates_vision1_interp.txt 不存在，跳過該資料夾
# 檔案 D:/labdata/MOCAP/recordings_copy/受試者104\recording_20250214_114309\yolo_skeleton_coordinates_vision1_interp.txt 不存在，跳過該資料夾
# 檔案 D:/labdata/MOCAP/recordings_copy/受試者104\recording_20250214_114754\yolo_skeleton_coordinates_vision1_interp.txt 不存在，跳過該資料夾
# 檔案 D:/labdata/MOCAP/recordings_copy/受試者104\recording_20250214_115400\yolo_skeleton_coordinates_vision1_interp.txt 不存在，跳過該資料夾
# 檔案 D:/labdata/MOCAP/recordings_copy/受試者104\recording_20250214_115756\yolo_skeleton_coordinates_vision1_interp.txt 不存在，跳過該資料夾
# 檔案 D:/labdata/MOCAP/recordings_copy/受試者104\recording_20250214_120245\yolo_skeleton_coordinates_vision1_interp.txt 不存在，跳過該資料夾
# 檔案 D:/labdata/MOCAP/recordings_copy/受試者104\recording_20250214_123313_棋盤\yolo_skeleton_coordinates_vision1_interp.txt 不存在，跳過該資料夾
# 檔案 D:/labdata/MOCAP/recordings_copy/受試者105\recording_20250226_112450\yolo_skeleton_coordinates_vision1_interp.txt 不存在，跳過該資料夾
# 檔案 D:/labdata/MOCAP/recordings_copy/受試者105\recording_20250226_112605\yolo_skeleton_coordinates_vision1_interp.txt 不存在，跳過該資料夾
# 檔案 D:/labdata/MOCAP/recordings_copy/受試者105\recording_20250226_112921\yolo_skeleton_coordinates_vision1_interp.txt 不存在，跳過該資料夾
# 檔案 D:/labdata/MOCAP/recordings_copy/受試者105\recording_20250226_113050\yolo_skeleton_coordinates_vision1_interp.txt 不存在，跳過該資料夾
# 檔案 D:/labdata/MOCAP/recordings_copy/受試者105\recording_20250226_113742\yolo_skeleton_coordinates_vision1_interp.txt 不存在，跳過該資料夾
# 檔案 D:/labdata/MOCAP/recordings_copy/受試者106壞\recording_20250306_135311\yolo_skeleton_coordinates_vision1_interp.txt 不存在，跳過該資料夾
# 檔案 D:/labdata/MOCAP/recordings_copy/受試者106壞\recording_20250306_135517\yolo_skeleton_coordinates_vision1_interp.txt 不存在，跳過該資料夾
# 檔案 D:/labdata/MOCAP/recordings_copy/受試者106壞\recording_20250306_135727\yolo_skeleton_coordinates_vision1_interp.txt 不存在，跳過該資料夾
# 檔案 D:/labdata/MOCAP/recordings_copy/受試者106壞\recording_20250306_135859\yolo_skeleton_coordinates_vision1_interp.txt 不存在，跳過該資料夾
# 檔案 D:/labdata/MOCAP/recordings_copy/受試者106壞\recording_20250306_140155\yolo_skeleton_coordinates_vision1_interp.txt 不存在，跳過該資料夾
# 檔案 D:/labdata/MOCAP/recordings_copy/受試者106壞\recording_20250306_140441棋盤\yolo_skeleton_coordinates_vision1_interp.txt 不存在，跳過該資料夾
# 檔案 D:/labdata/MOCAP/recordings_copy/受試者107\recording_20250311_113957\yolo_skeleton_coordinates_vision1_interp.txt 不存在，跳過該資料夾
# 檔案 D:/labdata/MOCAP/recordings_copy/受試者107\recording_20250311_114224\yolo_skeleton_coordinates_vision1_interp.txt 不存在，跳過該資料夾
# 檔案 D:/labdata/MOCAP/recordings_copy/受試者107\recording_20250311_114339\yolo_skeleton_coordinates_vision1_interp.txt 不存在，跳過該資料夾
# 檔案 D:/labdata/MOCAP/recordings_copy/受試者107\recording_20250311_114511\yolo_skeleton_coordinates_vision1_interp.txt 不存在，跳過該資料夾
# 檔案 D:/labdata/MOCAP/recordings_copy/受試者107\recording_20250311_114804\yolo_skeleton_coordinates_vision1_interp.txt 不存在，跳過該資料夾
# 檔案 D:/labdata/MOCAP/recordings_copy/受試者107\recording_20250311_115905_棋盤\yolo_skeleton_coordinates_vision1_interp.txt 不存在，跳過該資料夾
# 檔案 D:/labdata/MOCAP/recordings_copy/受試者11\recording_20241204_094919棋盤\yolo_skeleton_coordinates_vision1_interp.txt 不存在，跳過該資料夾
# [98, 206, 300, 431, 566, 659, 770, 884, 984, 1090] [206, 300, 431, 566, 659, 770, 884, 984, 1090, 1181]
# D:/labdata/MOCAP/recordings_copy/受試者11\recording_20241204_111646\left_knee_angle_plot.png
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者11\recording_20241204_111646\skeleton_vision1\skeleton_1.txt（Y 變化範圍: 375.00）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者11\recording_20241204_111646\skeleton_vision1\skeleton_2.txt（Y 變化範圍: 358.05）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者11\recording_20241204_111646\skeleton_vision1\skeleton_3.txt（Y 變化範圍: 367.13）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者11\recording_20241204_111646\skeleton_vision1\skeleton_4.txt（Y 變化範圍: 364.07）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者11\recording_20241204_111646\skeleton_vision1\skeleton_5.txt（Y 變化範圍: 326.42）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者11\recording_20241204_111646\skeleton_vision1\skeleton_6.txt（Y 變化範圍: 335.03）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者11\recording_20241204_111646\skeleton_vision1\skeleton_7.txt（Y 變化範圍: 341.21）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者11\recording_20241204_111646\skeleton_vision1\skeleton_8.txt（Y 變化範圍: 347.60）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者11\recording_20241204_111646\skeleton_vision1\skeleton_9.txt（Y 變化範圍: 338.28）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者11\recording_20241204_111646\skeleton_vision1\skeleton_10.txt（Y 變化範圍: 325.57）
# 所有骨架數據處理完成！
# [139, 284, 394, 603, 693, 801, 934, 1042, 1136] [284, 394, 527, 693, 801, 934, 1042, 1136, 1184]
# D:/labdata/MOCAP/recordings_copy/受試者11\recording_20241204_112004\left_knee_angle_plot.png
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者11\recording_20241204_112004\skeleton_vision1\skeleton_1.txt（Y 變化範圍: 354.69）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者11\recording_20241204_112004\skeleton_vision1\skeleton_2.txt（Y 變化範圍: 353.52）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者11\recording_20241204_112004\skeleton_vision1\skeleton_3.txt（Y 變化範圍: 361.59）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者11\recording_20241204_112004\skeleton_vision1\skeleton_4.txt（Y 變化範圍: 346.33）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者11\recording_20241204_112004\skeleton_vision1\skeleton_5.txt（Y 變化範圍: 358.84）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者11\recording_20241204_112004\skeleton_vision1\skeleton_6.txt（Y 變化範圍: 361.43）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者11\recording_20241204_112004\skeleton_vision1\skeleton_7.txt（Y 變化範圍: 339.72）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者11\recording_20241204_112004\skeleton_vision1\skeleton_8.txt（Y 變化範圍: 350.54）
# 跳過骨架數據 9（X 變化範圍: 0.47，過小）
# 所有骨架數據處理完成！
# [123, 263, 370, 500, 597, 725, 835, 957, 1085, 1198, 1330, 1445] [263, 370, 500, 597, 725, 835, 957, 1085, 1198, 1330, 1445, 1480]
# D:/labdata/MOCAP/recordings_copy/受試者11\recording_20241204_112324\left_knee_angle_plot.png
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者11\recording_20241204_112324\skeleton_vision1\skeleton_1.txt（Y 變化範圍: 319.57）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者11\recording_20241204_112324\skeleton_vision1\skeleton_2.txt（Y 變化範圍: 330.84）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者11\recording_20241204_112324\skeleton_vision1\skeleton_3.txt（Y 變化範圍: 336.54）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者11\recording_20241204_112324\skeleton_vision1\skeleton_4.txt（Y 變化範圍: 343.39）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者11\recording_20241204_112324\skeleton_vision1\skeleton_5.txt（Y 變化範圍: 332.08）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者11\recording_20241204_112324\skeleton_vision1\skeleton_6.txt（Y 變化範圍: 335.23）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者11\recording_20241204_112324\skeleton_vision1\skeleton_7.txt（Y 變化範圍: 352.02）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者11\recording_20241204_112324\skeleton_vision1\skeleton_8.txt（Y 變化範圍: 326.60）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者11\recording_20241204_112324\skeleton_vision1\skeleton_9.txt（Y 變化範圍: 324.22）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者11\recording_20241204_112324\skeleton_vision1\skeleton_10.txt（Y 變化範圍: 342.45）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者11\recording_20241204_112324\skeleton_vision1\skeleton_11.txt（Y 變化範圍: 354.36）
# 跳過骨架數據 12（X 變化範圍: 0.53，過小）
# 所有骨架數據處理完成！
# [84, 247, 372, 523, 670, 818, 952, 1062, 1256, 1361, 1542, 1705, 1833] [247, 372, 498, 670, 818, 952, 1062, 1238, 1361, 1526, 1659, 1833, 1872]
# D:/labdata/MOCAP/recordings_copy/受試者11\recording_20241204_112725\left_knee_angle_plot.png
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者11\recording_20241204_112725\skeleton_vision1\skeleton_1.txt（Y 變化範圍: 393.89）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者11\recording_20241204_112725\skeleton_vision1\skeleton_2.txt（Y 變化範圍: 414.29）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者11\recording_20241204_112725\skeleton_vision1\skeleton_3.txt（Y 變化範圍: 390.62）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者11\recording_20241204_112725\skeleton_vision1\skeleton_4.txt（Y 變化範圍: 381.49）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者11\recording_20241204_112725\skeleton_vision1\skeleton_5.txt（Y 變化範圍: 384.58）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者11\recording_20241204_112725\skeleton_vision1\skeleton_6.txt（Y 變化範圍: 381.03）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者11\recording_20241204_112725\skeleton_vision1\skeleton_7.txt（Y 變化範圍: 393.66）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者11\recording_20241204_112725\skeleton_vision1\skeleton_8.txt（Y 變化範圍: 374.36）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者11\recording_20241204_112725\skeleton_vision1\skeleton_9.txt（Y 變化範圍: 378.03）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者11\recording_20241204_112725\skeleton_vision1\skeleton_10.txt（Y 變化範圍: 363.03）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者11\recording_20241204_112725\skeleton_vision1\skeleton_11.txt（Y 變化範圍: 392.33）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者11\recording_20241204_112725\skeleton_vision1\skeleton_12.txt（Y 變化範圍: 375.34）
# 跳過骨架數據 13（X 變化範圍: 0.41，過小）
# 所有骨架數據處理完成！
# 跳過重疊片段：(202, 339) 和上一段重疊 42 幀
# [28, 108, 202, 339, 531, 658, 818, 945, 1090, 1204, 1324] [108, 202, 244, 492, 636, 818, 943, 1044, 1174, 1324, 1457]
# D:/labdata/MOCAP/recordings_copy/受試者11\recording_20241204_113115\left_knee_angle_plot.png
# 跳過骨架數據 1（X 變化範圍: 0.69，過小）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者11\recording_20241204_113115\skeleton_vision1\skeleton_2.txt（Y 變化範圍: 349.17）
# 跳過骨架數據 3（X 變化範圍: 0.43，過小）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者11\recording_20241204_113115\skeleton_vision1\skeleton_4.txt（Y 變化範圍: 332.72）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者11\recording_20241204_113115\skeleton_vision1\skeleton_5.txt（Y 變化範圍: 335.30）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者11\recording_20241204_113115\skeleton_vision1\skeleton_6.txt（Y 變化範圍: 341.03）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者11\recording_20241204_113115\skeleton_vision1\skeleton_7.txt（Y 變化範圍: 355.55）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者11\recording_20241204_113115\skeleton_vision1\skeleton_8.txt（Y 變化範圍: 336.17）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者11\recording_20241204_113115\skeleton_vision1\skeleton_9.txt（Y 變化範圍: 311.16）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者11\recording_20241204_113115\skeleton_vision1\skeleton_10.txt（Y 變化範圍: 330.25）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者11\recording_20241204_113115\skeleton_vision1\skeleton_11.txt（Y 變化範圍: 333.71）
# 所有骨架數據處理完成！
# 檔案 D:/labdata/MOCAP/recordings_copy/受試者12\recording_20241204_094919棋盤\yolo_skeleton_coordinates_vision1_interp.txt 不存在，跳過該資料夾
# [75, 195, 310, 434, 544, 661, 773, 910, 1015, 1141] [195, 310, 434, 544, 661, 773, 910, 1015, 1141, 1238]
# D:/labdata/MOCAP/recordings_copy/受試者12\recording_20241204_111740\left_knee_angle_plot.png
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者12\recording_20241204_111740\skeleton_vision1\skeleton_1.txt（Y 變化範圍: 396.05）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者12\recording_20241204_111740\skeleton_vision1\skeleton_2.txt（Y 變化範圍: 397.21）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者12\recording_20241204_111740\skeleton_vision1\skeleton_3.txt（Y 變化範圍: 390.21）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者12\recording_20241204_111740\skeleton_vision1\skeleton_4.txt（Y 變化範圍: 376.74）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者12\recording_20241204_111740\skeleton_vision1\skeleton_5.txt（Y 變化範圍: 369.81）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者12\recording_20241204_111740\skeleton_vision1\skeleton_6.txt（Y 變化範圍: 374.10）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者12\recording_20241204_111740\skeleton_vision1\skeleton_7.txt（Y 變化範圍: 394.52）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者12\recording_20241204_111740\skeleton_vision1\skeleton_8.txt（Y 變化範圍: 387.42）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者12\recording_20241204_111740\skeleton_vision1\skeleton_9.txt（Y 變化範圍: 373.60）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者12\recording_20241204_111740\skeleton_vision1\skeleton_10.txt（Y 變化範圍: 383.99）
# 所有骨架數據處理完成！
# [0, 217, 336, 438, 563, 684, 773, 929, 1029, 1129, 1260, 1382, 1493] [145, 336, 438, 563, 684, 773, 898, 1029, 1129, 1260, 1382, 1493, 1523]
# D:/labdata/MOCAP/recordings_copy/受試者12\recording_20241204_112102\left_knee_angle_plot.png
# 跳過骨架數據 1（X 變化範圍: 8.60，過小）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者12\recording_20241204_112102\skeleton_vision1\skeleton_2.txt（Y 變化範圍: 424.14）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者12\recording_20241204_112102\skeleton_vision1\skeleton_3.txt（Y 變化範圍: 413.72）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者12\recording_20241204_112102\skeleton_vision1\skeleton_4.txt（Y 變化範圍: 399.71）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者12\recording_20241204_112102\skeleton_vision1\skeleton_5.txt（Y 變化範圍: 410.30）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者12\recording_20241204_112102\skeleton_vision1\skeleton_6.txt（Y 變化範圍: 420.15）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者12\recording_20241204_112102\skeleton_vision1\skeleton_7.txt（Y 變化範圍: 422.69）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者12\recording_20241204_112102\skeleton_vision1\skeleton_8.txt（Y 變化範圍: 400.49）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者12\recording_20241204_112102\skeleton_vision1\skeleton_9.txt（Y 變化範圍: 404.21）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者12\recording_20241204_112102\skeleton_vision1\skeleton_10.txt（Y 變化範圍: 415.28）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者12\recording_20241204_112102\skeleton_vision1\skeleton_11.txt（Y 變化範圍: 428.17）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者12\recording_20241204_112102\skeleton_vision1\skeleton_12.txt（Y 變化範圍: 427.47）
# 跳過骨架數據 13（X 變化範圍: 0.24，過小）
# 所有骨架數據處理完成！
# 跳過重疊片段：(129, 242) 和上一段重疊 113 幀
# 跳過重疊片段：(1073, 1202) 和上一段重疊 129 幀
# 跳過重疊片段：(1566, 1674) 和上一段重疊 108 幀
# [0, 129, 276, 386, 489, 613, 774, 892, 1073, 1202, 1359, 1451, 1566, 1692] [94, 242, 386, 489, 613, 768, 892, 1025, 1202, 1359, 1451, 1554, 1674, 1736]
# D:/labdata/MOCAP/recordings_copy/受試者12\recording_20241204_112431\left_knee_angle_plot.png
# 跳過骨架數據 1（X 變化範圍: 1.21，過小）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者12\recording_20241204_112431\skeleton_vision1\skeleton_2.txt（Y 變化範圍: 435.48）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者12\recording_20241204_112431\skeleton_vision1\skeleton_3.txt（Y 變化範圍: 427.43）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者12\recording_20241204_112431\skeleton_vision1\skeleton_4.txt（Y 變化範圍: 422.17）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者12\recording_20241204_112431\skeleton_vision1\skeleton_5.txt（Y 變化範圍: 429.61）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者12\recording_20241204_112431\skeleton_vision1\skeleton_6.txt（Y 變化範圍: 420.10）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者12\recording_20241204_112431\skeleton_vision1\skeleton_7.txt（Y 變化範圍: 400.22）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者12\recording_20241204_112431\skeleton_vision1\skeleton_8.txt（Y 變化範圍: 420.36）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者12\recording_20241204_112431\skeleton_vision1\skeleton_9.txt（Y 變化範圍: 417.38）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者12\recording_20241204_112431\skeleton_vision1\skeleton_10.txt（Y 變化範圍: 426.93）
# 跳過骨架數據 11（X 變化範圍: 37.28，過小）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者12\recording_20241204_112431\skeleton_vision1\skeleton_12.txt（Y 變化範圍: 424.30）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者12\recording_20241204_112431\skeleton_vision1\skeleton_13.txt（Y 變化範圍: 418.59）
# 跳過骨架數據 14（X 變化範圍: 0.66，過小）
# 所有骨架數據處理完成！
# [38, 226, 339, 479, 624, 763, 911, 1091, 1247, 1406, 1563, 1705, 1855, 1994] [183, 339, 479, 624, 763, 875, 1070, 1247, 1405, 1563, 1705, 1855, 1994, 2108]
# D:/labdata/MOCAP/recordings_copy/受試者12\recording_20241204_112840\left_knee_angle_plot.png
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者12\recording_20241204_112840\skeleton_vision1\skeleton_1.txt（Y 變化範圍: 398.56）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者12\recording_20241204_112840\skeleton_vision1\skeleton_2.txt（Y 變化範圍: 386.33）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者12\recording_20241204_112840\skeleton_vision1\skeleton_3.txt（Y 變化範圍: 398.60）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者12\recording_20241204_112840\skeleton_vision1\skeleton_4.txt（Y 變化範圍: 387.81）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者12\recording_20241204_112840\skeleton_vision1\skeleton_5.txt（Y 變化範圍: 386.00）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者12\recording_20241204_112840\skeleton_vision1\skeleton_6.txt（Y 變化範圍: 379.30）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者12\recording_20241204_112840\skeleton_vision1\skeleton_7.txt（Y 變化範圍: 404.85）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者12\recording_20241204_112840\skeleton_vision1\skeleton_8.txt（Y 變化範圍: 390.39）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者12\recording_20241204_112840\skeleton_vision1\skeleton_9.txt（Y 變化範圍: 390.21）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者12\recording_20241204_112840\skeleton_vision1\skeleton_10.txt（Y 變化範圍: 395.51）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者12\recording_20241204_112840\skeleton_vision1\skeleton_11.txt（Y 變化範圍: 380.45）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者12\recording_20241204_112840\skeleton_vision1\skeleton_12.txt（Y 變化範圍: 389.72）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/受試者12\recording_20241204_112840\skeleton_vision1\skeleton_13.txt（Y 變化範圍: 389.66）
# ...
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/翰為1\recording_20241121_101637\skeleton_vision1\skeleton_1.txt（Y 變化範圍: 296.82）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/翰為1\recording_20241121_101637\skeleton_vision1\skeleton_2.txt（Y 變化範圍: 331.84）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/翰為1\recording_20241121_101637\skeleton_vision1\skeleton_3.txt（Y 變化範圍: 319.30）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/翰為1\recording_20241121_101637\skeleton_vision1\skeleton_4.txt（Y 變化範圍: 324.72）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/翰為1\recording_20241121_101637\skeleton_vision1\skeleton_5.txt（Y 變化範圍: 317.44）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/翰為1\recording_20241121_101637\skeleton_vision1\skeleton_6.txt（Y 變化範圍: 300.93）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/翰為1\recording_20241121_101637\skeleton_vision1\skeleton_7.txt（Y 變化範圍: 353.90）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/翰為1\recording_20241121_101637\skeleton_vision1\skeleton_8.txt（Y 變化範圍: 338.72）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/翰為1\recording_20241121_101637\skeleton_vision1\skeleton_9.txt（Y 變化範圍: 338.94）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/翰為1\recording_20241121_101637\skeleton_vision1\skeleton_10.txt（Y 變化範圍: 352.46）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/翰為1\recording_20241121_101637\skeleton_vision1\skeleton_11.txt（Y 變化範圍: 335.68）
# 所有骨架數據處理完成！
# [47, 237, 394, 576, 726, 891, 1038, 1202, 1373, 1530, 1691, 1851] [221, 394, 550, 726, 875, 1038, 1202, 1353, 1530, 1682, 1851, 1996]
# D:/labdata/MOCAP/recordings_copy/翰為1\recording_20241121_104413\left_knee_angle_plot.png
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/翰為1\recording_20241121_104413\skeleton_vision1\skeleton_1.txt（Y 變化範圍: 320.46）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/翰為1\recording_20241121_104413\skeleton_vision1\skeleton_2.txt（Y 變化範圍: 311.41）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/翰為1\recording_20241121_104413\skeleton_vision1\skeleton_3.txt（Y 變化範圍: 323.76）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/翰為1\recording_20241121_104413\skeleton_vision1\skeleton_4.txt（Y 變化範圍: 332.84）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/翰為1\recording_20241121_104413\skeleton_vision1\skeleton_5.txt（Y 變化範圍: 320.15）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/翰為1\recording_20241121_104413\skeleton_vision1\skeleton_6.txt（Y 變化範圍: 327.66）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/翰為1\recording_20241121_104413\skeleton_vision1\skeleton_7.txt（Y 變化範圍: 314.05）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/翰為1\recording_20241121_104413\skeleton_vision1\skeleton_8.txt（Y 變化範圍: 323.36）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/翰為1\recording_20241121_104413\skeleton_vision1\skeleton_9.txt（Y 變化範圍: 338.62）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/翰為1\recording_20241121_104413\skeleton_vision1\skeleton_10.txt（Y 變化範圍: 335.25）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/翰為1\recording_20241121_104413\skeleton_vision1\skeleton_11.txt（Y 變化範圍: 333.32）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/翰為1\recording_20241121_104413\skeleton_vision1\skeleton_12.txt（Y 變化範圍: 304.01）
# 所有骨架數據處理完成！
# [103, 262, 429, 612, 806, 971, 1181, 1357, 1522, 1709] [233, 388, 556, 746, 927, 1105, 1307, 1505, 1663, 1829]
# D:/labdata/MOCAP/recordings_copy/翰為1\recording_20241121_110932\left_knee_angle_plot.png
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/翰為1\recording_20241121_110932\skeleton_vision1\skeleton_1.txt（Y 變化範圍: 335.94）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/翰為1\recording_20241121_110932\skeleton_vision1\skeleton_2.txt（Y 變化範圍: 344.02）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/翰為1\recording_20241121_110932\skeleton_vision1\skeleton_3.txt（Y 變化範圍: 338.14）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/翰為1\recording_20241121_110932\skeleton_vision1\skeleton_4.txt（Y 變化範圍: 333.78）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/翰為1\recording_20241121_110932\skeleton_vision1\skeleton_5.txt（Y 變化範圍: 354.72）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/翰為1\recording_20241121_110932\skeleton_vision1\skeleton_6.txt（Y 變化範圍: 326.90）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/翰為1\recording_20241121_110932\skeleton_vision1\skeleton_7.txt（Y 變化範圍: 293.48）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/翰為1\recording_20241121_110932\skeleton_vision1\skeleton_8.txt（Y 變化範圍: 335.77）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/翰為1\recording_20241121_110932\skeleton_vision1\skeleton_9.txt（Y 變化範圍: 320.37）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/翰為1\recording_20241121_110932\skeleton_vision1\skeleton_10.txt（Y 變化範圍: 333.85）
# 所有骨架數據處理完成！
# [96, 228, 351, 511, 667, 797, 960, 1114, 1245] [228, 351, 494, 641, 797, 941, 1114, 1245, 1387]
# D:/labdata/MOCAP/recordings_copy/翰為1\recording_20241121_111134\left_knee_angle_plot.png
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/翰為1\recording_20241121_111134\skeleton_vision1\skeleton_1.txt（Y 變化範圍: 275.46）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/翰為1\recording_20241121_111134\skeleton_vision1\skeleton_2.txt（Y 變化範圍: 276.34）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/翰為1\recording_20241121_111134\skeleton_vision1\skeleton_3.txt（Y 變化範圍: 268.71）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/翰為1\recording_20241121_111134\skeleton_vision1\skeleton_4.txt（Y 變化範圍: 272.54）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/翰為1\recording_20241121_111134\skeleton_vision1\skeleton_5.txt（Y 變化範圍: 295.82）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/翰為1\recording_20241121_111134\skeleton_vision1\skeleton_6.txt（Y 變化範圍: 299.63）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/翰為1\recording_20241121_111134\skeleton_vision1\skeleton_7.txt（Y 變化範圍: 284.89）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/翰為1\recording_20241121_111134\skeleton_vision1\skeleton_8.txt（Y 變化範圍: 296.46）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/翰為1\recording_20241121_111134\skeleton_vision1\skeleton_9.txt（Y 變化範圍: 294.13）
# 所有骨架數據處理完成！
# 檔案 D:/labdata/MOCAP/recordings_copy/翰為1\recording_20241121_152241棋盤\yolo_skeleton_coordinates_vision1_interp.txt 不存在，跳過該資料夾
# 檔案 D:/labdata/MOCAP/recordings_copy/老師6\recording_20241125_152951棋盤\yolo_skeleton_coordinates_vision1_interp.txt 不存在，跳過該資料夾
# [14, 111, 200, 279, 372, 469, 558, 659, 755] [111, 200, 279, 372, 469, 558, 659, 755, 832]
# D:/labdata/MOCAP/recordings_copy/老師6\recording_20241125_164657\left_knee_angle_plot.png
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/老師6\recording_20241125_164657\skeleton_vision1\skeleton_1.txt（Y 變化範圍: 313.33）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/老師6\recording_20241125_164657\skeleton_vision1\skeleton_2.txt（Y 變化範圍: 314.49）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/老師6\recording_20241125_164657\skeleton_vision1\skeleton_3.txt（Y 變化範圍: 320.98）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/老師6\recording_20241125_164657\skeleton_vision1\skeleton_4.txt（Y 變化範圍: 333.72）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/老師6\recording_20241125_164657\skeleton_vision1\skeleton_5.txt（Y 變化範圍: 317.05）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/老師6\recording_20241125_164657\skeleton_vision1\skeleton_6.txt（Y 變化範圍: 318.23）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/老師6\recording_20241125_164657\skeleton_vision1\skeleton_7.txt（Y 變化範圍: 325.82）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/老師6\recording_20241125_164657\skeleton_vision1\skeleton_8.txt（Y 變化範圍: 326.37）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/老師6\recording_20241125_164657\skeleton_vision1\skeleton_9.txt（Y 變化範圍: 316.57）
# 所有骨架數據處理完成！
# [78, 143, 218, 308, 381, 455, 538, 597, 688, 745, 830, 916, 973, 1073, 1149, 1228, 1301, 1396] [143, 218, 308, 381, 455, 538, 597, 688, 745, 830, 916, 973, 1073, 1149, 1228, 1301, 1396, 1452]
# D:/labdata/MOCAP/recordings_copy/老師6\recording_20241125_164745\left_knee_angle_plot.png
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/老師6\recording_20241125_164745\skeleton_vision1\skeleton_1.txt（Y 變化範圍: 320.11）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/老師6\recording_20241125_164745\skeleton_vision1\skeleton_2.txt（Y 變化範圍: 321.23）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/老師6\recording_20241125_164745\skeleton_vision1\skeleton_3.txt（Y 變化範圍: 321.08）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/老師6\recording_20241125_164745\skeleton_vision1\skeleton_4.txt（Y 變化範圍: 319.85）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/老師6\recording_20241125_164745\skeleton_vision1\skeleton_5.txt（Y 變化範圍: 337.65）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/老師6\recording_20241125_164745\skeleton_vision1\skeleton_6.txt（Y 變化範圍: 315.58）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/老師6\recording_20241125_164745\skeleton_vision1\skeleton_7.txt（Y 變化範圍: 308.38）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/老師6\recording_20241125_164745\skeleton_vision1\skeleton_8.txt（Y 變化範圍: 295.67）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/老師6\recording_20241125_164745\skeleton_vision1\skeleton_9.txt（Y 變化範圍: 308.95）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/老師6\recording_20241125_164745\skeleton_vision1\skeleton_10.txt（Y 變化範圍: 309.11）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/老師6\recording_20241125_164745\skeleton_vision1\skeleton_11.txt（Y 變化範圍: 328.12）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/老師6\recording_20241125_164745\skeleton_vision1\skeleton_12.txt（Y 變化範圍: 310.18）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/老師6\recording_20241125_164745\skeleton_vision1\skeleton_13.txt（Y 變化範圍: 321.48）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/老師6\recording_20241125_164745\skeleton_vision1\skeleton_14.txt（Y 變化範圍: 316.48）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/老師6\recording_20241125_164745\skeleton_vision1\skeleton_15.txt（Y 變化範圍: 330.12）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/老師6\recording_20241125_164745\skeleton_vision1\skeleton_16.txt（Y 變化範圍: 322.51）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/老師6\recording_20241125_164745\skeleton_vision1\skeleton_17.txt（Y 變化範圍: 316.45）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/老師6\recording_20241125_164745\skeleton_vision1\skeleton_18.txt（Y 變化範圍: 293.22）
# 所有骨架數據處理完成！
# 跳過重疊片段：(1598, 1708) 和上一段重疊 110 幀
# 跳過重疊片段：(1958, 2060) 和上一段重疊 72 幀
# [56, 145, 242, 347, 449, 555, 661, 760, 855, 963, 1076, 1210, 1337, 1462, 1598, 1743, 1856, 1958] [145, 242, 347, 449, 555, 661, 760, 855, 963, 1076, 1210, 1337, 1462, 1598, 1708, 1856, 1955, 2030]
# D:/labdata/MOCAP/recordings_copy/老師6\recording_20241125_164856\left_knee_angle_plot.png
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/老師6\recording_20241125_164856\skeleton_vision1\skeleton_1.txt（Y 變化範圍: 286.71）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/老師6\recording_20241125_164856\skeleton_vision1\skeleton_2.txt（Y 變化範圍: 308.73）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/老師6\recording_20241125_164856\skeleton_vision1\skeleton_3.txt（Y 變化範圍: 311.63）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/老師6\recording_20241125_164856\skeleton_vision1\skeleton_4.txt（Y 變化範圍: 321.74）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/老師6\recording_20241125_164856\skeleton_vision1\skeleton_5.txt（Y 變化範圍: 296.80）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/老師6\recording_20241125_164856\skeleton_vision1\skeleton_6.txt（Y 變化範圍: 305.44）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/老師6\recording_20241125_164856\skeleton_vision1\skeleton_7.txt（Y 變化範圍: 314.76）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/老師6\recording_20241125_164856\skeleton_vision1\skeleton_8.txt（Y 變化範圍: 309.36）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/老師6\recording_20241125_164856\skeleton_vision1\skeleton_9.txt（Y 變化範圍: 329.93）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/老師6\recording_20241125_164856\skeleton_vision1\skeleton_10.txt（Y 變化範圍: 290.19）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/老師6\recording_20241125_164856\skeleton_vision1\skeleton_11.txt（Y 變化範圍: 293.34）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/老師6\recording_20241125_164856\skeleton_vision1\skeleton_12.txt（Y 變化範圍: 293.74）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/老師6\recording_20241125_164856\skeleton_vision1\skeleton_13.txt（Y 變化範圍: 281.30）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/老師6\recording_20241125_164856\skeleton_vision1\skeleton_14.txt（Y 變化範圍: 291.28）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/老師6\recording_20241125_164856\skeleton_vision1\skeleton_15.txt（Y 變化範圍: 293.36）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/老師6\recording_20241125_164856\skeleton_vision1\skeleton_16.txt（Y 變化範圍: 293.04）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/老師6\recording_20241125_164856\skeleton_vision1\skeleton_17.txt（Y 變化範圍: 289.55）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/老師6\recording_20241125_164856\skeleton_vision1\skeleton_18.txt（Y 變化範圍: 309.65）
# 所有骨架數據處理完成！
# [89, 188, 272, 366, 449, 534, 615, 706, 800, 921, 1034, 1125, 1230, 1304, 1401, 1485] [188, 272, 366, 449, 534, 615, 706, 800, 921, 1034, 1125, 1230, 1304, 1401, 1485, 1576]
# D:/labdata/MOCAP/recordings_copy/老師6\recording_20241125_165017\left_knee_angle_plot.png
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/老師6\recording_20241125_165017\skeleton_vision1\skeleton_1.txt（Y 變化範圍: 279.54）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/老師6\recording_20241125_165017\skeleton_vision1\skeleton_2.txt（Y 變化範圍: 277.55）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/老師6\recording_20241125_165017\skeleton_vision1\skeleton_3.txt（Y 變化範圍: 266.93）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/老師6\recording_20241125_165017\skeleton_vision1\skeleton_4.txt（Y 變化範圍: 300.12）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/老師6\recording_20241125_165017\skeleton_vision1\skeleton_5.txt（Y 變化範圍: 294.44）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/老師6\recording_20241125_165017\skeleton_vision1\skeleton_6.txt（Y 變化範圍: 280.99）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/老師6\recording_20241125_165017\skeleton_vision1\skeleton_7.txt（Y 變化範圍: 290.94）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/老師6\recording_20241125_165017\skeleton_vision1\skeleton_8.txt（Y 變化範圍: 290.72）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/老師6\recording_20241125_165017\skeleton_vision1\skeleton_9.txt（Y 變化範圍: 280.04）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/老師6\recording_20241125_165017\skeleton_vision1\skeleton_10.txt（Y 變化範圍: 280.05）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/老師6\recording_20241125_165017\skeleton_vision1\skeleton_11.txt（Y 變化範圍: 290.81）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/老師6\recording_20241125_165017\skeleton_vision1\skeleton_12.txt（Y 變化範圍: 292.91）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/老師6\recording_20241125_165017\skeleton_vision1\skeleton_13.txt（Y 變化範圍: 277.78）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/老師6\recording_20241125_165017\skeleton_vision1\skeleton_14.txt（Y 變化範圍: 289.29）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/老師6\recording_20241125_165017\skeleton_vision1\skeleton_15.txt（Y 變化範圍: 283.21）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/老師6\recording_20241125_165017\skeleton_vision1\skeleton_16.txt（Y 變化範圍: 283.17）
# 所有骨架數據處理完成！
# 跳過重疊片段：(171, 304) 和上一段重疊 46 幀
# [69, 171, 304, 415, 528, 635, 770, 877, 972, 1059, 1170, 1278, 1386] [161, 217, 415, 528, 635, 770, 877, 972, 1059, 1170, 1278, 1386, 1428]
# D:/labdata/MOCAP/recordings_copy/老師6\recording_20241125_165126\left_knee_angle_plot.png
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/老師6\recording_20241125_165126\skeleton_vision1\skeleton_1.txt（Y 變化範圍: 303.21）
# 跳過骨架數據 2（X 變化範圍: 2.66，過小）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/老師6\recording_20241125_165126\skeleton_vision1\skeleton_3.txt（Y 變化範圍: 327.75）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/老師6\recording_20241125_165126\skeleton_vision1\skeleton_4.txt（Y 變化範圍: 326.22）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/老師6\recording_20241125_165126\skeleton_vision1\skeleton_5.txt（Y 變化範圍: 318.10）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/老師6\recording_20241125_165126\skeleton_vision1\skeleton_6.txt（Y 變化範圍: 300.24）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/老師6\recording_20241125_165126\skeleton_vision1\skeleton_7.txt（Y 變化範圍: 293.17）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/老師6\recording_20241125_165126\skeleton_vision1\skeleton_8.txt（Y 變化範圍: 316.56）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/老師6\recording_20241125_165126\skeleton_vision1\skeleton_9.txt（Y 變化範圍: 310.72）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/老師6\recording_20241125_165126\skeleton_vision1\skeleton_10.txt（Y 變化範圍: 317.30）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/老師6\recording_20241125_165126\skeleton_vision1\skeleton_11.txt（Y 變化範圍: 302.30）
# 骨架數據儲存: D:/labdata/MOCAP/recordings_copy/老師6\recording_20241125_165126\skeleton_vision1\skeleton_12.txt（Y 變化範圍: 306.24）
# 跳過骨架數據 13（X 變化範圍: 5.65，過小）
# 所有骨架數據處理完成！

# %%
import cv2

def main():
    # 讀取影片
    video_path = "D:\\labdata\\MOCAP\\recordings_copy\\受試者11\\recording_20241204_113115\\vision1.avi"  # 請將此處替換為影片的路徑
    cap = cv2.VideoCapture(video_path)

    if not cap.isOpened():
        print("無法開啟影片")
        return

    paused = False
    frame_number = 0
    pause_points_1 = []  # 第一個矩陣
    pause_points_2 = []  # 第二個矩陣
    pause_count = 0  # 記錄目前暫停的次數

    def mouse_callback(event, x, y, flags, param):
        nonlocal paused, pause_count
        if event == cv2.EVENT_LBUTTONDOWN:
            paused = not paused
            if paused:
                print(f"暫停於幀數: {frame_number}")
                
#                 交替存入兩個矩陣
                if pause_count % 2 == 0:
                    pause_points_1.append(frame_number)
                else:
                    pause_points_2.append(frame_number)
#                 pause_points_1.append(frame_number)
                pause_count += 1  # 增加計數

    while True:
        if not paused:
            ret, frame = cap.read()
            if not ret:
                print("影片播放結束或讀取錯誤")
                break
            frame_number = int(cap.get(cv2.CAP_PROP_POS_FRAMES))

        # 顯示影片畫面
        cv2.imshow("Video", frame)

        # 設定滑鼠事件
        cv2.setMouseCallback("Video", mouse_callback)

        # 等待鍵盤或滑鼠事件
        key = cv2.waitKey(30) & 0xFF
        
        if key == ord('q'):
            print("退出程式")
            break

    # 顯示儲存的暫停幀數
    print("第一個矩陣 (pause_points_1):", pause_points_1)
    print("第二個矩陣 (pause_points_2):", pause_points_2)

    # 釋放資源
    cap.release()
    cv2.destroyAllWindows()

if __name__ == "__main__":
    main()
# Out:
# 暫停於幀數: 99
# 暫停於幀數: 202
# 暫停於幀數: 221
# 暫停於幀數: 332
# 暫停於幀數: 370
# 暫停於幀數: 492
# 暫停於幀數: 526
# 暫停於幀數: 635
# 暫停於幀數: 670
# 暫停於幀數: 768
# 暫停於幀數: 801
# 暫停於幀數: 896
# 暫停於幀數: 918
# 暫停於幀數: 1051
# 暫停於幀數: 1084
# 暫停於幀數: 1194
# 暫停於幀數: 1223
# 暫停於幀數: 1329
# 暫停於幀數: 1354
# 暫停於幀數: 1444
# 影片播放結束或讀取錯誤
# 第一個矩陣 (pause_points_1): [99, 221, 370, 526, 670, 801, 918, 1084, 1223, 1354]
# 第二個矩陣 (pause_points_2): [202, 332, 492, 635, 768, 896, 1051, 1194, 1329, 1444]

# %%
import os
path1 = "D:\\labdata\\MOCAP\\recordings_copy\\受試者11\\recording_20241204_113115\\"
skeleton_file_path = os.path.join(path1, 'yolo_skeleton_coordinates_1st_interp.txt')
bar_file_path1 = os.path.join(path1, 'yolo_coordinates_interpolated.txt')
video_path = os.path.join(path1, 'vision1.avi')
output_folder = os.path.join(path1, 'clips')
output_folder1 = os.path.join(path1, 'skeleton')
output_folder2 = os.path.join(path1, 'bar')
P1 = [99, 221, 370, 526, 670, 801, 918, 1084, 1223, 1354]
P2 = [202, 332, 492, 635, 768, 896, 1051, 1194, 1329, 1444]
split_video(video_path, output_folder, P1,P2,bar_file_path1, fps=30)
split_skeleton_data(skeleton_file_path, output_folder1,P1,P2,bar_file_path1)
split_bar_data(bar_file_path1, output_folder2, P1, P2,bar_file_path1)
# Out:
# 影片儲存: D:\labdata\MOCAP\recordings_copy\受試者11\recording_20241204_113115\clips\clip_1.mp4（X 變化範圍: 349.27）
# 影片儲存: D:\labdata\MOCAP\recordings_copy\受試者11\recording_20241204_113115\clips\clip_2.mp4（X 變化範圍: 340.34）
# 影片儲存: D:\labdata\MOCAP\recordings_copy\受試者11\recording_20241204_113115\clips\clip_3.mp4（X 變化範圍: 332.60）
# 影片儲存: D:\labdata\MOCAP\recordings_copy\受試者11\recording_20241204_113115\clips\clip_4.mp4（X 變化範圍: 335.30）
# 影片儲存: D:\labdata\MOCAP\recordings_copy\受試者11\recording_20241204_113115\clips\clip_5.mp4（X 變化範圍: 341.03）
# 影片儲存: D:\labdata\MOCAP\recordings_copy\受試者11\recording_20241204_113115\clips\clip_6.mp4（X 變化範圍: 355.55）
# 影片儲存: D:\labdata\MOCAP\recordings_copy\受試者11\recording_20241204_113115\clips\clip_7.mp4（X 變化範圍: 337.14）
# 影片儲存: D:\labdata\MOCAP\recordings_copy\受試者11\recording_20241204_113115\clips\clip_8.mp4（X 變化範圍: 335.75）
# 影片儲存: D:\labdata\MOCAP\recordings_copy\受試者11\recording_20241204_113115\clips\clip_9.mp4（X 變化範圍: 330.25）
# 影片儲存: D:\labdata\MOCAP\recordings_copy\受試者11\recording_20241204_113115\clips\clip_10.mp4（X 變化範圍: 331.01）
# 所有片段處理完成！
# 骨架數據儲存: D:\labdata\MOCAP\recordings_copy\受試者11\recording_20241204_113115\skeleton\skeleton_1.txt（Y 變化範圍: 349.27）
# 骨架數據儲存: D:\labdata\MOCAP\recordings_copy\受試者11\recording_20241204_113115\skeleton\skeleton_2.txt（Y 變化範圍: 340.34）
# 骨架數據儲存: D:\labdata\MOCAP\recordings_copy\受試者11\recording_20241204_113115\skeleton\skeleton_3.txt（Y 變化範圍: 332.60）
# 骨架數據儲存: D:\labdata\MOCAP\recordings_copy\受試者11\recording_20241204_113115\skeleton\skeleton_4.txt（Y 變化範圍: 335.30）
# 骨架數據儲存: D:\labdata\MOCAP\recordings_copy\受試者11\recording_20241204_113115\skeleton\skeleton_5.txt（Y 變化範圍: 341.03）
# 骨架數據儲存: D:\labdata\MOCAP\recordings_copy\受試者11\recording_20241204_113115\skeleton\skeleton_6.txt（Y 變化範圍: 355.55）
# 骨架數據儲存: D:\labdata\MOCAP\recordings_copy\受試者11\recording_20241204_113115\skeleton\skeleton_7.txt（Y 變化範圍: 337.14）
# 骨架數據儲存: D:\labdata\MOCAP\recordings_copy\受試者11\recording_20241204_113115\skeleton\skeleton_8.txt（Y 變化範圍: 335.75）
# 骨架數據儲存: D:\labdata\MOCAP\recordings_copy\受試者11\recording_20241204_113115\skeleton\skeleton_9.txt（Y 變化範圍: 330.25）
# 骨架數據儲存: D:\labdata\MOCAP\recordings_copy\受試者11\recording_20241204_113115\skeleton\skeleton_10.txt（Y 變化範圍: 331.01）
# 所有骨架數據處理完成！
# 槓鈴數據儲存: D:\labdata\MOCAP\recordings_copy\受試者11\recording_20241204_113115\bar\bar_1.txt（X 變化範圍: 349.27）
# 槓鈴數據儲存: D:\labdata\MOCAP\recordings_copy\受試者11\recording_20241204_113115\bar\bar_2.txt（X 變化範圍: 340.34）
# 槓鈴數據儲存: D:\labdata\MOCAP\recordings_copy\受試者11\recording_20241204_113115\bar\bar_3.txt（X 變化範圍: 332.60）
# 槓鈴數據儲存: D:\labdata\MOCAP\recordings_copy\受試者11\recording_20241204_113115\bar\bar_4.txt（X 變化範圍: 335.30）
# 槓鈴數據儲存: D:\labdata\MOCAP\recordings_copy\受試者11\recording_20241204_113115\bar\bar_5.txt（X 變化範圍: 341.03）
# 槓鈴數據儲存: D:\labdata\MOCAP\recordings_copy\受試者11\recording_20241204_113115\bar\bar_6.txt（X 變化範圍: 355.55）
# 槓鈴數據儲存: D:\labdata\MOCAP\recordings_copy\受試者11\recording_20241204_113115\bar\bar_7.txt（X 變化範圍: 337.14）
# 槓鈴數據儲存: D:\labdata\MOCAP\recordings_copy\受試者11\recording_20241204_113115\bar\bar_8.txt（X 變化範圍: 335.75）
# 槓鈴數據儲存: D:\labdata\MOCAP\recordings_copy\受試者11\recording_20241204_113115\bar\bar_9.txt（X 變化範圍: 330.25）
# 槓鈴數據儲存: D:\labdata\MOCAP\recordings_copy\受試者11\recording_20241204_113115\bar\bar_10.txt（X 變化範圍: 331.01）
# 所有槓鈴數據處理完成！

# %%
##把angle.txt按2d bar的幀數來切割影像
import os
import pandas as pd

root_dir = "D:\\labdata\\MOCAP\\recordings_copy\\受試者19\\recording_20241206_113600"
output_folder_name = "angle_int"

for category in os.listdir(root_dir):
    category_path = os.path.join(root_dir, category)
    if not os.path.isdir(category_path):
        continue

    for recording in os.listdir(category_path):
        recording_path = os.path.join(category_path, recording)
        bar_path = os.path.join(root_dir, "bar")
        angle_path = os.path.join(root_dir, "yolo_skeleton_coordinates_vision1_interp.txt")
        output_path = os.path.join(root_dir, output_folder_name)

        if not os.path.exists(bar_path) or not os.path.isfile(angle_path):
            continue

        # 讀 angle.txt（用空格分隔）
        angle_df = pd.read_csv(angle_path, header=None, delim_whitespace=True)

        # 創建輸出資料夾
        os.makedirs(output_path, exist_ok=True)

        # 遍歷每個 bar/*.txt
        for file_name in sorted(os.listdir(bar_path)):
            if not file_name.endswith(".txt"):
                continue
            bar_file = os.path.join(bar_path, file_name)

            # 讀 bar 檔：取第一列與最後一列的第一個值（用逗號分隔）
            with open(bar_file, "r") as f:
                lines = f.readlines()
                if not lines:
                    continue
                start_frame = int(lines[0].strip().split(",")[0])
                end_frame = int(lines[-1].strip().split(",")[0])

            # 從 angle_df 中擷取對應幀數區間
            sub_angle_df = angle_df[(angle_df[0] >= start_frame) & (angle_df[0] <= end_frame)]

            # 存成新檔案（用逗號分隔）
            angle_output_name = f"angle_{os.path.splitext(file_name)[0].split('_')[-1]}.txt"
            sub_angle_df.to_csv(os.path.join(output_path, angle_output_name), index=False, header=False, sep=',')
# Out:
# ---------------------------------------------------
# TypeError         Traceback (most recent call last)
# Cell In[4], line 43
#      40     end_frame = int(lines[-1].strip().split(",")[0])
#      42 # 從 angle_df 中擷取對應幀數區間
# ---> 43 sub_angle_df = angle_df[(angle_df[0] >= start_frame) & (angle_df[0] <= end_frame)]
#      45 # 存成新檔案（用逗號分隔）
#      46 angle_output_name = f"angle_{os.path.splitext(file_name)[0].split('_')[-1]}.txt"
#
# File ~\Anaconda3\envs\deadlift\lib\site-packages\pandas\core\ops\common.py:72, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      68             return NotImplemented
#      70 other = item_from_zerodim(other)
# ---> 72 return method(self, other)
#
# File ~\Anaconda3\envs\deadlift\lib\site-packages\pandas\core\arraylike.py:62, in OpsMixin.__ge__(self, other)
#      60 @unpack_zerodim_and_defer("__ge__")
#      61 def __ge__(self, other):
# ---> 62     return self._cmp_method(other, operator.ge)
#
# File ~\Anaconda3\envs\deadlift\lib\site-packages\pandas\core\series.py:6243, in Series._cmp_method(self, other, op)
#    6240 rvalues = extract_array(other, extract_numpy=True, extract_range=True)
#    6242 with np.errstate(all="ignore"):
# -> 6243     res_values = ops.comparison_op(lvalues, rvalues, op)
#    6245 return self._construct_result(res_values, name=res_name)
#
# File ~\Anaconda3\envs\deadlift\lib\site-packages\pandas\core\ops\array_ops.py:287, in comparison_op(left, right, op)
#     284     return invalid_comparison(lvalues, rvalues, op)
#     286 elif is_object_dtype(lvalues.dtype) or isinstance(rvalues, str):
# --> 287     res_values = comp_method_OBJECT_ARRAY(op, lvalues, rvalues)
#     289 else:
#     290     res_values = _na_arithmetic_op(lvalues, rvalues, op, is_cmp=True)
#
# File ~\Anaconda3\envs\deadlift\lib\site-packages\pandas\core\ops\array_ops.py:75, in comp_method_OBJECT_ARRAY(op, x, y)
#      73     result = libops.vec_compare(x.ravel(), y.ravel(), op)
#      74 else:
# ---> 75     result = libops.scalar_compare(x.ravel(), y, op)
#      76 return result.reshape(x.shape)
#
# File ~\Anaconda3\envs\deadlift\lib\site-packages\pandas\_libs\ops.pyx:107, in pandas._libs.ops.scalar_compare()
#
# TypeError: '>=' not supported between instances of 'str' and 'int'
